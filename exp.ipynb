# %%
import math
import numpy as np
from scqbf.scqbf_instance import *
from scqbf.scqbf_evaluator import *
import random
import time

# %%
instance = read_max_sc_qbf_instance("instances/sample_instances/1.txt")
instance
# Out:
# ScQbfInstance(n=5, subsets=[{1, 2}, {2, 3, 4}, {1, 4}, {3, 5}, {4, 5}], A=[[3.0, 1.0, -2.0, 0.0, 3.0], [0.0, -1.0, 2.0, 1.0, -1.0], [0.0, 0.0, 2.0, -2.0, 4.0], [0.0, 0.0, 0.0, 0.0, 5.0], [0.0, 0.0, 0.0, 0.0, 3.0]])

# %%
eval = ScQbfEvaluator(instance)

# %%
sample_solution = ScQbfSolution([1, 2])
eval.evaluate_coverage(sample_solution)
# Out:
# 0.8

# %%
class ScQbfGrasp:
    
    def __init__(self, instance: ScQbfInstance, iterations,
                 config: dict = {
                    "construction_method": "traditional",  # traditional | random_plus_greedy | sampled_greedy
                    "construction_args": (),
                    "local_search_method": "best_improve"  # best_improve | first_improve
                 }, time_limit_secs: float = None):
        self.instance = instance
        self.iterations = iterations
        self.config = config
        self.time_limit_secs = time_limit_secs
        self.solve_time = 0
        self.evaluator = ScQbfEvaluator(instance)


    def solve(self) -> ScQbfSolution:
        if self.instance is None:
            raise ValueError("Problem instance is not initialized")
        
        best_sol = ScQbfSolution([])
        start_time = time.perf_counter()
        for i in range(self.iterations):
            constructed_sol = self._constructive_heuristic()
            print(f"Constructed solution (iteration {i}): {constructed_sol.elements}")
            
            if not self.evaluator.is_solution_valid(constructed_sol):
                print("Constructed solution is not feasible, fixing...")
                constructed_sol = self._fix_solution(constructed_sol)
            
            sol = self._local_search(constructed_sol)
            
            if (self.evaluator.evaluate_objfun(sol) > self.evaluator.evaluate_objfun(best_sol)):
                best_sol = sol
            
            self.solve_time = time.perf_counter() - start_time
            if self.time_limit_secs is not None and self.solve_time >= self.time_limit_secs:
                break
            
        return best_sol
    
    def _fix_solution(self, sol: ScQbfSolution) -> ScQbfSolution:
        """
        This function is called when the constructed solution is not feasible.
        It'll add the most covering elements until the solution is feasible.
        """
        while not self.evaluator.is_solution_valid(sol):
            cl = [i for i in range(self.instance.n) if i not in sol.elements]
            best_cand = None
            best_coverage = -1
            
            for cand in cl:
                coverage = self.evaluator.evaluate_insertion_delta_coverage(cand, sol)
                if coverage > best_coverage:
                    best_coverage = coverage
                    best_cand = cand
            
            if best_cand is not None:
                sol.elements.append(best_cand)
            else:
                break
        
        if not self.evaluator.is_solution_valid(sol):
            raise ValueError("Could not fix the solution to be feasible")
        
        return sol

    def _constructive_heuristic(self) -> ScQbfSolution:
        if self.config["construction_method"] == "traditional":
            alpha = self.config["construction_args"][0] if len(self.config.get("construction_args", [])) > 0 else 0.5
            return self._constructive_heuristic_traditional(alpha)

        elif self.config["construction_method"] == "random_plus_greedy":
            alpha, p = self.config["construction_args"] if len(self.config.get("construction_args", [])) > 0 else (0.5, self.instance.n // 2)
            return self._constructive_heuristic_random_plus_greedy(alpha, p)
        
        elif self.config["construction_method"] == "sampled_greedy":
            p = self.config["construction_args"][0] if len(self.config.get("construction_args", [])) > 0 else self.instance.n // 10
            return self._constructive_heuristic_sampled_greedy(p)
        
        else:
            return self._constructive_heuristic_traditional()

    def _constructive_heuristic_traditional(self, alpha: float) -> ScQbfSolution:
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            # traditional constructive heuristic
            rcl = []
            min_delta = math.inf
            max_delta = -math.inf
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun < min_delta:
                    min_delta = delta_objfun
                if delta_objfun > max_delta:
                    max_delta = delta_objfun
            
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun >= (min_delta + alpha * (max_delta - min_delta)):

                    ## ONLY add to rcl if coverage increases
                    if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0:
                        rcl.append(candidate_element)

            # Randomly select an element from the RCL to add to the solution
            if rcl:
                chosen_element = random.choice(rcl)
                constructed_sol.elements.append(chosen_element)

        return constructed_sol

    def _constructive_heuristic_random_plus_greedy(self, alpha: float, p: float):
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        # TODO make p represent percentage of the solution
        for _ in range(p):
            rcl = []
            min_delta = math.inf
            max_delta = -math.inf
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun < min_delta:
                    min_delta = delta_objfun
                if delta_objfun > max_delta:
                    max_delta = delta_objfun
            
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun >= (min_delta + alpha * (max_delta - min_delta)):

                    ## ONLY add to rcl if coverage increases
                    if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0:
                        rcl.append(candidate_element)

            # Randomly select an element from the RCL to add to the solution
            if rcl:
                chosen_element = random.choice(rcl)
                constructed_sol.elements.append(chosen_element)
            
            if not (prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)):
                break

        prev_objfun = float("-inf")

        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            best_delta = float("-inf")
            best_cand_in = -1
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                ## ONLY add to rcl if coverage increases
                if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0 \
                and delta_objfun > best_delta \
                and prev_objfun < self.evaluator.evaluate_objfun(constructed_sol):
                    best_cand_in = candidate_element
                    best_delta = delta_objfun
            
            if (best_cand_in >= 0):
                constructed_sol.elements.append(best_cand_in)

        return constructed_sol
    
    def _constructive_heuristic_sampled_greedy(self, p: int):
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            rcl = random.sample(cl, min(len(cl), p))
            best_delta = float("-inf")
            best_cand_in = None
            for candidate_element in rcl:
                delta = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta > best_delta:
                    best_delta = delta
                    best_cand_in = candidate_element
            
            if best_delta > 0 and best_cand_in is not None:
                constructed_sol.elements.append(best_cand_in)
            else:
                break
        
        return constructed_sol

    ####################

    def _local_search(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        if self.config.get("local_search_method", False) == "best_improve":
            return self._local_search_best_improve(starting_point)
        elif self.config.get("local_search_method", False) == "first_improve":
            return self._local_search_first_improve(starting_point)


    def _local_search_best_improve(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        sol = ScQbfSolution(starting_point.elements.copy())
        
        _search_iterations = 0
        
        while True:
            _search_iterations += 1
            
            best_delta = float("-inf")
            best_cand_in = None
            best_cand_out = None

            cl = [i for i in range(self.instance.n) if i not in sol.elements]

            # Evaluate insertions
            for cand_in in cl:
                delta = self.evaluator.evaluate_insertion_delta(cand_in, sol)
                if delta > best_delta:
                    best_delta = delta
                    best_cand_in = cand_in
                    best_cand_out = None

            # Evaluate removals
            for cand_out in sol.elements:
                delta = self.evaluator.evaluate_removal_delta(cand_out, sol)
                if delta > best_delta:
                    # Check if removing this element would break feasibility
                    temp_sol = ScQbfSolution(sol.elements.copy())
                    temp_sol.elements.remove(cand_out)
                    if self.evaluator.is_solution_valid(temp_sol):
                        best_delta = delta
                        best_cand_in = None
                        best_cand_out = cand_out

            # Evaluate exchanges
            for cand_in in cl:
                for cand_out in sol.elements:
                    delta = self.evaluator.evaluate_exchange_delta(cand_in, cand_out, sol)
                    if delta > best_delta:
                        # Check if this exchange would break feasibility
                        temp_sol = ScQbfSolution(sol.elements.copy())
                        temp_sol.elements.remove(cand_out)
                        temp_sol.elements.append(cand_in)
                        if self.evaluator.is_solution_valid(temp_sol):
                            best_delta = delta
                            best_cand_in = cand_in
                            best_cand_out = cand_out

            # Apply the best move if it improves the solution
            if best_delta > 0:  # Positive delta means improvement for maximization
                print(f"[local_search]: Improvement found! Delta: {best_delta}, in {best_cand_in}, out {best_cand_out}")
                if best_cand_in is not None:
                    sol.elements.append(best_cand_in)
                if best_cand_out is not None:
                    sol.elements.remove(best_cand_out)

                self.evaluator.evaluate_objfun(sol)
            else:
                print(f"[local_search]: No improvement found after ({_search_iterations}) iterations!")
                break  # No improving move found
        
        return sol

    def _local_search_first_improve(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        sol = ScQbfSolution(starting_point.elements.copy())
        _search_iterations = 0
        
        while True:
            _search_iterations += 1
            improvement_found = False
            
            cl = [i for i in range(self.instance.n) if i not in sol.elements]

            # Insertions
            for cand_in in cl:
                delta = self.evaluator.evaluate_insertion_delta(cand_in, sol)
                if delta > 0:
                    print(f"[local_search]: First improvement found (insertion)! Delta: {delta}, in {cand_in}")
                    sol.elements.append(cand_in)
                    self.evaluator.evaluate_objfun(sol)
                    improvement_found = True
                    break
            
            if improvement_found:
                continue
            
            # Removals
            for cand_out in sol.elements:
                delta = self.evaluator.evaluate_removal_delta(cand_out, sol)
                if delta > 0: 
                    # Check if removing this element would break feasibility
                    temp_sol = ScQbfSolution(sol.elements.copy())
                    temp_sol.elements.remove(cand_out)
                    if self.evaluator.is_solution_valid(temp_sol):
                        print(f"[local_search]: First improvement found (removal)! Delta: {delta}, out {cand_out}")
                        sol.elements.remove(cand_out)
                        self.evaluator.evaluate_objfun(sol)
                        improvement_found = True
            
            if improvement_found:
                continue

            # Exchanges
            for cand_in in cl:
                for cand_out in sol.elements:
                    delta = self.evaluator.evaluate_exchange_delta(cand_in, cand_out, sol)
                    if delta > 0:
                        # Check if this exchange would break feasibility
                        temp_sol = ScQbfSolution(sol.elements.copy())
                        temp_sol.elements.remove(cand_out)
                        temp_sol.elements.append(cand_in)
                        if self.evaluator.is_solution_valid(temp_sol):
                            print(f"[local_search]: First improvement found (exchange)! Delta: {delta}, in {cand_in}, out {cand_out}")
                            sol.elements.remove(cand_out)
                            sol.elements.append(cand_in)
                            self.evaluator.evaluate_objfun(sol)
                            improvement_found = True
                            break
                
                if improvement_found:
                    break

            if improvement_found:
                continue
            print(f"[local_search]: No improvement found after ({_search_iterations}) iterations!")
            break
        
        return sol

# %%
# Test the ScQbfGrasp implementation
instance = read_max_sc_qbf_instance("instances/sample_instances/2.txt")
grasp = ScQbfGrasp(instance, iterations=10)

print("Testing GRASP algorithm...")
print(f"Instance size: n = {instance.n}")
print(f"Number of subsets: {len(instance.subsets)}")

# Run GRASP
best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print()

# Test with different alpha values
print("\nTesting different alpha values:")
alphas = [0.0, 0.3, 0.7, 1.0]
for alpha in alphas:
    grasp_test = ScQbfGrasp(instance, iterations=5, config={
        "construction_method": "traditional",
        "construction_args": (alpha,),
        "local_search_method": "best_improve"
    })
    solution = grasp_test.solve()
    obj_val = evaluator.evaluate_objfun(solution)
    coverage = evaluator.evaluate_coverage(solution)
    print(f"Alpha {alpha}: Obj={obj_val:.2f}, Coverage={coverage:.2%}, Solution={solution.elements}")
    print()
# Out:
# Testing GRASP algorithm...
# Instance size: n = 3
# Number of subsets: 3
# Constructed solution (iteration 0): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 5): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 6): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 7): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 8): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 9): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
#
# Best solution found:
# Selected elements: [2, 1, 0]
# Objective value: 7.5
# Coverage: 100.00%
#
#
# Testing different alpha values:
# Constructed solution (iteration 0): [2, 0]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [0, 2]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [0, 2]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.0: Obj=7.50, Coverage=100.00%, Solution=[2, 0, 1]
#
# Constructed solution (iteration 0): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.3: Obj=7.50, Coverage=100.00%, Solution=[2, 1, 0]
#
# Constructed solution (iteration 0): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.7: Obj=7.50, Coverage=100.00%, Solution=[1, 0, 2]
#
# Constructed solution (iteration 0): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 1.0: Obj=7.50, Coverage=100.00%, Solution=[1, 0, 2]

# %% [markdown]
# ### Testing sampled greedy construction

# %%
instance = read_max_sc_qbf_instance("instances/sample_instances/2.txt")
grasp = ScQbfGrasp(instance, iterations=10, config={
    "construction_method": "sampled_greedy",
    "construction_args": (instance.n // 10,),
    "local_search_method": "first_improve"
}
)

best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print()
# Out:
# Constructed solution (iteration 0): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 5): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 6): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 7): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 8): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 9): []
# Constructed solution is not feasible, fixing...
# [local_search]: First improvement found (insertion)! Delta: 1.5, in 2
# [local_search]: No improvement found after (2) iterations!
#
# Best solution found:
# Selected elements: [0, 1, 2]
# Objective value: 7.5
# Coverage: 100.00%

# %% [markdown]
# # Testing on larger instances

# %%
instance = read_max_sc_qbf_instance("instances/gen1/instance5.txt")
grasp = ScQbfGrasp(instance, iterations=10, config={
    "construction_method": "random_plus_greedy",
    "construction_args": (),
    "local_search_method": "first_improve"
},
)

best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print(f"Elapsed time: {grasp.solve_time:.2f} seconds")
print()
# Out:
# Constructed solution (iteration 0): [56, 59, 93, 74, 26, 5, 10, 9, 90, 69]
# [local_search]: First improvement found (insertion)! Delta: 11.31000000000001, in 0
# [local_search]: First improvement found (insertion)! Delta: 19.520000000000003, in 3
# [local_search]: First improvement found (insertion)! Delta: 10.249999999999998, in 7
# [local_search]: First improvement found (insertion)! Delta: 0.620000000000001, in 2
# [local_search]: First improvement found (insertion)! Delta: 4.85, in 6
# [local_search]: First improvement found (insertion)! Delta: 1.7500000000000013, in 8
# [local_search]: First improvement found (insertion)! Delta: 73.31, in 12
# [local_search]: First improvement found (insertion)! Delta: 18.790000000000003, in 16
# [local_search]: First improvement found (insertion)! Delta: 4.1899999999999995, in 21
# [local_search]: First improvement found (insertion)! Delta: 1.7200000000000006, in 15
# [local_search]: First improvement found (insertion)! Delta: 0.4400000000000013, in 18
# [local_search]: First improvement found (insertion)! Delta: 11.23, in 19
# [local_search]: First improvement found (insertion)! Delta: 5.53, in 17
# [local_search]: First improvement found (insertion)! Delta: 0.5699999999999976, in 13
# [local_search]: First improvement found (insertion)! Delta: 22.27, in 23
# [local_search]: First improvement found (insertion)! Delta: 54.61, in 28
# [local_search]: First improvement found (insertion)! Delta: 5.5500000000000025, in 20
# [local_search]: First improvement found (insertion)! Delta: 10.57, in 27
# [local_search]: First improvement found (insertion)! Delta: 8.949999999999996, in 30
# [local_search]: First improvement found (insertion)! Delta: 17.570000000000014, in 32
# [local_search]: First improvement found (insertion)! Delta: 33.18000000000001, in 35
# [local_search]: First improvement found (insertion)! Delta: 6.850000000000003, in 37
# [local_search]: First improvement found (insertion)! Delta: 7.510000000000001, in 25
# [local_search]: First improvement found (insertion)! Delta: 3.969999999999999, in 39
# [local_search]: First improvement found (insertion)! Delta: 17.650000000000006, in 41
# [local_search]: First improvement found (insertion)! Delta: 25.880000000000003, in 44
# [local_search]: First improvement found (insertion)! Delta: 3.150000000000005, in 24
# [local_search]: First improvement found (insertion)! Delta: 4.390000000000005, in 46
# [local_search]: First improvement found (insertion)! Delta: 7.499999999999998, in 4
# [local_search]: First improvement found (insertion)! Delta: 3.3100000000000014, in 36
# [local_search]: First improvement found (insertion)! Delta: 2.920000000000014, in 45
# [local_search]: First improvement found (insertion)! Delta: 64.9, in 47
# [local_search]: First improvement found (insertion)! Delta: 12.41, in 50
# [local_search]: First improvement found (insertion)! Delta: 77.56999999999998, in 51
# [local_search]: First improvement found (insertion)! Delta: 87.19999999999995, in 53
# [local_search]: First improvement found (insertion)! Delta: 14.15000000000001, in 58
# [local_search]: First improvement found (insertion)! Delta: 76.20999999999998, in 61
# [local_search]: First improvement found (insertion)! Delta: 62.049999999999976, in 62
# [local_search]: First improvement found (insertion)! Delta: 1.7599999999999933, in 48
# [local_search]: First improvement found (insertion)! Delta: 5.2499999999999964, in 54
# [local_search]: First improvement found (insertion)! Delta: 47.660000000000004, in 66
# [local_search]: First improvement found (insertion)! Delta: 27.339999999999996, in 70
# [local_search]: First improvement found (insertion)! Delta: 42.330000000000005, in 72
# [local_search]: First improvement found (insertion)! Delta: 23.620000000000005, in 73
# [local_search]: First improvement found (insertion)! Delta: 76.8, in 77
# [local_search]: First improvement found (insertion)! Delta: 4.039999999999983, in 75
# [local_search]: First improvement found (insertion)! Delta: 1.7199999999999989, in 78
# [local_search]: First improvement found (insertion)! Delta: 39.52, in 80
# [local_search]: First improvement found (insertion)! Delta: 17.299999999999983, in 85
# [local_search]: First improvement found (insertion)! Delta: 47.81, in 92
# [local_search]: First improvement found (insertion)! Delta: 5.880000000000004, in 55
# [local_search]: First improvement found (insertion)! Delta: 1.3400000000000105, in 49
# [local_search]: First improvement found (insertion)! Delta: 3.780000000000008, in 42
# [local_search]: First improvement found (insertion)! Delta: 3.2200000000000175, in 63
# [local_search]: First improvement found (insertion)! Delta: 34.02, in 95
# [local_search]: First improvement found (insertion)! Delta: 17.61, in 97
# [local_search]: First improvement found (removal)! Delta: 30.13, out 5
# [local_search]: First improvement found (removal)! Delta: 24.56000000000001, out 7
# [local_search]: First improvement found (removal)! Delta: 12.46000000000001, out 21
# [local_search]: First improvement found (removal)! Delta: 1.8399999999999963, out 27
# [local_search]: First improvement found (removal)! Delta: 0.10000000000000142, out 24
# [local_search]: First improvement found (removal)! Delta: 21.779999999999994, out 36
# [local_search]: First improvement found (insertion)! Delta: 7.2199999999999935, in 21
# [local_search]: First improvement found (insertion)! Delta: 3.999999999999989, in 33
# [local_search]: First improvement found (removal)! Delta: 10.14, out 75
# [local_search]: First improvement found (insertion)! Delta: 2.3799999999999977, in 43
# [local_search]: First improvement found (exchange)! Delta: 1.3999999999999897, in 83, out 43
# [local_search]: First improvement found (removal)! Delta: 1.42, out 15
# [local_search]: First improvement found (insertion)! Delta: 8.730000000000011, in 88
# [local_search]: First improvement found (insertion)! Delta: 2.7099999999999973, in 79
# [local_search]: First improvement found (removal)! Delta: 3.8599999999999977, out 23
# [local_search]: First improvement found (removal)! Delta: 1.9799999999999773, out 21
# [local_search]: First improvement found (insertion)! Delta: 1.6400000000000037, in 87
# [local_search]: First improvement found (insertion)! Delta: 1.3200000000000136, in 96
# [local_search]: No improvement found after (69) iterations!
# Constructed solution (iteration 1): [47, 97, 84]
# [local_search]: First improvement found (insertion)! Delta: 11.059999999999999, in 0
# [local_search]: First improvement found (insertion)! Delta: 32.96, in 3
# [local_search]: First improvement found (insertion)! Delta: 1.8100000000000005, in 1
# [local_search]: First improvement found (insertion)! Delta: 6.84, in 5
# [local_search]: First improvement found (insertion)! Delta: 10.63, in 7
# [local_search]: First improvement found (insertion)! Delta: 25.24, in 9
# [local_search]: First improvement found (insertion)! Delta: 8.250000000000004, in 11
# [local_search]: First improvement found (insertion)! Delta: 24.850000000000005, in 12
# [local_search]: First improvement found (insertion)! Delta: 22.37, in 13
# [local_search]: First improvement found (insertion)! Delta: 34.010000000000005, in 14
# [local_search]: First improvement found (insertion)! Delta: 4.759999999999998, in 15
# [local_search]: First improvement found (insertion)! Delta: 1.9200000000000044, in 16
# [local_search]: First improvement found (insertion)! Delta: 1.42, in 2
# [local_search]: First improvement found (insertion)! Delta: 21.470000000000002, in 17
# [local_search]: First improvement found (insertion)! Delta: 21.67, in 19
# [local_search]: First improvement found (insertion)! Delta: 19.0, in 21
# [local_search]: First improvement found (insertion)! Delta: 1.5999999999999988, in 10
# [local_search]: First improvement found (insertion)! Delta: 2.040000000000001, in 6
# [local_search]: First improvement found (insertion)! Delta: 1.2500000000000018, in 24
# [local_search]: First improvement found (insertion)! Delta: 3.5500000000000025, in 18
# [local_search]: First improvement found (insertion)! Delta: 5.300000000000002, in 26
# [local_search]: First improvement found (insertion)! Delta: 14.21, in 28
# [local_search]: First improvement found (insertion)! Delta: 14.129999999999997, in 32
# [local_search]: First improvement found (insertion)! Delta: 4.73, in 23
# [local_search]: First improvement found (insertion)! Delta: 9.46, in 35
# [local_search]: First improvement found (insertion)! Delta: 6.860000000000006, in 25
# [local_search]: First improvement found (insertion)! Delta: 1.7000000000000028, in 37
# [local_search]: First improvement found (insertion)! Delta: 16.42, in 41
# [local_search]: First improvement found (insertion)! Delta: 2.569999999999998, in 8
# [local_search]: First improvement found (insertion)! Delta: 3.760000000000008, in 4
# [local_search]: First improvement found (insertion)! Delta: 16.28, in 38
# [local_search]: First improvement found (insertion)! Delta: 26.439999999999994, in 44
# [local_search]: First improvement found (insertion)! Delta: 7.920000000000003, in 30
# [local_search]: First improvement found (insertion)! Delta: 1.5099999999999962, in 39
# [local_search]: First improvement found (insertion)! Delta: 5.580000000000002, in 45
# [local_search]: First improvement found (insertion)! Delta: 8.709999999999999, in 50
# [local_search]: First improvement found (insertion)! Delta: 32.519999999999996, in 51
# [local_search]: First improvement found (insertion)! Delta: 80.10999999999997, in 53
# [local_search]: First improvement found (insertion)! Delta: 0.36999999999999167, in 42
# [local_search]: First improvement found (insertion)! Delta: 4.809999999999999, in 54
# [local_search]: First improvement found (insertion)! Delta: 16.939999999999998, in 55
# [local_search]: First improvement found (insertion)! Delta: 42.760000000000005, in 56
# [local_search]: First improvement found (insertion)! Delta: 0.6500000000000039, in 49
# [local_search]: First improvement found (insertion)! Delta: 69.35, in 59
# [local_search]: First improvement found (insertion)! Delta: 89.85999999999999, in 61
# [local_search]: First improvement found (insertion)! Delta: 14.260000000000005, in 62
# [local_search]: First improvement found (insertion)! Delta: 43.55999999999998, in 66
# [local_search]: First improvement found (insertion)! Delta: 5.249999999999995, in 67
# [local_search]: First improvement found (insertion)! Delta: 3.7599999999999976, in 70
# [local_search]: First improvement found (insertion)! Delta: 9.159999999999998, in 71
# [local_search]: First improvement found (insertion)! Delta: 68.86, in 72
# [local_search]: First improvement found (insertion)! Delta: 10.729999999999993, in 73
# [local_search]: First improvement found (insertion)! Delta: 29.41, in 74
# [local_search]: First improvement found (insertion)! Delta: 76.90000000000002, in 77
# [local_search]: First improvement found (insertion)! Delta: 71.07, in 80
# [local_search]: First improvement found (insertion)! Delta: 11.229999999999999, in 83
# [local_search]: First improvement found (insertion)! Delta: 8.149999999999993, in 48
# [local_search]: First improvement found (insertion)! Delta: 20.700000000000014, in 86
# [local_search]: First improvement found (insertion)! Delta: 4.169999999999992, in 91
# [local_search]: First improvement found (insertion)! Delta: 1.79, in 34
# [local_search]: First improvement found (insertion)! Delta: 56.56, in 92
# [local_search]: First improvement found (insertion)! Delta: 33.13000000000002, in 93
# [local_search]: First improvement found (removal)! Delta: 23.620000000000008, out 84
# [local_search]: First improvement found (removal)! Delta: 24.150000000000006, out 5
# [local_search]: First improvement found (removal)! Delta: 22.93000000000001, out 11
# [local_search]: First improvement found (removal)! Delta: 28.46999999999999, out 14
# [local_search]: First improvement found (removal)! Delta: 7.989999999999998, out 21
# [local_search]: First improvement found (removal)! Delta: 3.0599999999999965, out 23
# [local_search]: First improvement found (removal)! Delta: 9.519999999999987, out 38
# [local_search]: First improvement found (removal)! Delta: 1.7299999999999933, out 49
# [local_search]: First improvement found (removal)! Delta: 13.350000000000009, out 66
# [local_search]: First improvement found (insertion)! Delta: 6.409999999999995, in 20
# [local_search]: First improvement found (insertion)! Delta: 11.970000000000002, in 23
# [local_search]: First improvement found (insertion)! Delta: 18.090000000000003, in 46
# [local_search]: First improvement found (insertion)! Delta: 10.270000000000003, in 63
# [local_search]: First improvement found (insertion)! Delta: 7.740000000000008, in 85
# [local_search]: First improvement found (insertion)! Delta: 6.909999999999993, in 89
# [local_search]: First improvement found (insertion)! Delta: 13.340000000000014, in 95
# [local_search]: First improvement found (insertion)! Delta: 0.05999999999999872, in 27
# [local_search]: First improvement found (insertion)! Delta: 0.6800000000000068, in 90
# [local_search]: First improvement found (insertion)! Delta: 3.7799999999999985, in 58
# [local_search]: First improvement found (removal)! Delta: 3.4799999999999986, out 7
# [local_search]: First improvement found (removal)! Delta: 22.529999999999998, out 15
# [local_search]: No improvement found after (75) iterations!
# Constructed solution (iteration 2): [34, 35, 77, 74, 32, 93, 81]
# [local_search]: First improvement found (insertion)! Delta: 12.77, in 0
# [local_search]: First improvement found (insertion)! Delta: 6.6099999999999985, in 3
# [local_search]: First improvement found (insertion)! Delta: 13.729999999999999, in 4
# [local_search]: First improvement found (insertion)! Delta: 3.5100000000000016, in 5
# [local_search]: First improvement found (insertion)! Delta: 4.640000000000001, in 7
# [local_search]: First improvement found (insertion)! Delta: 1.98, in 8
# [local_search]: First improvement found (insertion)! Delta: 28.37, in 9
# [local_search]: First improvement found (insertion)! Delta: 16.409999999999997, in 10
# [local_search]: First improvement found (insertion)! Delta: 24.76000000000001, in 12
# [local_search]: First improvement found (insertion)! Delta: 0.15000000000000036, in 2
# [local_search]: First improvement found (insertion)! Delta: 0.4000000000000039, in 6
# [local_search]: First improvement found (insertion)! Delta: 17.209999999999997, in 13
# [local_search]: First improvement found (insertion)! Delta: 13.389999999999999, in 14
# [local_search]: First improvement found (insertion)! Delta: 31.689999999999994, in 15
# [local_search]: First improvement found (insertion)! Delta: 15.75, in 16
# [local_search]: First improvement found (insertion)! Delta: 48.69, in 19
# [local_search]: First improvement found (insertion)! Delta: 16.600000000000005, in 23
# [local_search]: First improvement found (insertion)! Delta: 0.19000000000000128, in 20
# [local_search]: First improvement found (insertion)! Delta: 9.269999999999996, in 24
# [local_search]: First improvement found (insertion)! Delta: 2.639999999999997, in 18
# [local_search]: First improvement found (insertion)! Delta: 27.479999999999997, in 25
# [local_search]: First improvement found (insertion)! Delta: 25.539999999999996, in 26
# [local_search]: First improvement found (insertion)! Delta: 3.190000000000011, in 17
# [local_search]: First improvement found (insertion)! Delta: 19.229999999999997, in 27
# [local_search]: First improvement found (insertion)! Delta: 39.56999999999999, in 28
# [local_search]: First improvement found (insertion)! Delta: 32.980000000000004, in 37
# [local_search]: First improvement found (insertion)! Delta: 44.6, in 41
# [local_search]: First improvement found (insertion)! Delta: 10.140000000000004, in 43
# [local_search]: First improvement found (insertion)! Delta: 15.479999999999993, in 44
# [local_search]: First improvement found (insertion)! Delta: 17.28, in 45
# [local_search]: First improvement found (insertion)! Delta: 2.4499999999999975, in 39
# [local_search]: First improvement found (insertion)! Delta: 17.399999999999995, in 46
# [local_search]: First improvement found (insertion)! Delta: 47.32999999999999, in 47
# [local_search]: First improvement found (insertion)! Delta: 41.359999999999985, in 51
# [local_search]: First improvement found (insertion)! Delta: 0.6600000000000033, in 50
# [local_search]: First improvement found (insertion)! Delta: 49.56, in 53
# [local_search]: First improvement found (insertion)! Delta: 26.629999999999995, in 54
# [local_search]: First improvement found (insertion)! Delta: 18.799999999999994, in 56
# [local_search]: First improvement found (insertion)! Delta: 0.4599999999999902, in 58
# [local_search]: First improvement found (insertion)! Delta: 35.33, in 59
# [local_search]: First improvement found (insertion)! Delta: 8.109999999999992, in 36
# [local_search]: First improvement found (insertion)! Delta: 75.05000000000003, in 61
# [local_search]: First improvement found (insertion)! Delta: 57.99999999999998, in 62
# [local_search]: First improvement found (insertion)! Delta: 7.619999999999995, in 48
# [local_search]: First improvement found (insertion)! Delta: 31.66, in 66
# [local_search]: First improvement found (insertion)! Delta: 9.04999999999999, in 70
# [local_search]: First improvement found (insertion)! Delta: 12.810000000000016, in 71
# [local_search]: First improvement found (insertion)! Delta: 38.80000000000001, in 72
# [local_search]: First improvement found (insertion)! Delta: 8.019999999999998, in 73
# [local_search]: First improvement found (insertion)! Delta: 5.6800000000000015, in 75
# [local_search]: First improvement found (insertion)! Delta: 32.669999999999995, in 80
# [local_search]: First improvement found (insertion)! Delta: 17.850000000000012, in 86
# [local_search]: First improvement found (insertion)! Delta: 1.3900000000000023, in 1
# [local_search]: First improvement found (insertion)! Delta: 2.900000000000007, in 42
# [local_search]: First improvement found (insertion)! Delta: 14.450000000000005, in 90
# [local_search]: First improvement found (insertion)! Delta: 31.27999999999998, in 91
# [local_search]: First improvement found (insertion)! Delta: 52.78, in 92
# [local_search]: First improvement found (insertion)! Delta: 16.840000000000018, in 95
# [local_search]: First improvement found (insertion)! Delta: 53.77000000000001, in 97
# [local_search]: First improvement found (removal)! Delta: 16.460000000000015, out 81
# [local_search]: First improvement found (removal)! Delta: 19.140000000000004, out 5
# [local_search]: First improvement found (removal)! Delta: 66.03, out 14
# [local_search]: First improvement found (removal)! Delta: 10.560000000000002, out 36
# [local_search]: First improvement found (removal)! Delta: 18.890000000000015, out 75
# [local_search]: First improvement found (insertion)! Delta: 16.06, in 30
# [local_search]: First improvement found (insertion)! Delta: 4.349999999999998, in 63
# [local_search]: First improvement found (insertion)! Delta: 11.759999999999991, in 85
# [local_search]: First improvement found (insertion)! Delta: 7.679999999999991, in 55
# [local_search]: First improvement found (removal)! Delta: 10.02000000000001, out 7
# [local_search]: First improvement found (removal)! Delta: 2.969999999999999, out 13
# [local_search]: First improvement found (removal)! Delta: 1.7300000000000022, out 27
# [local_search]: First improvement found (removal)! Delta: 0.09999999999999343, out 66
# [local_search]: First improvement found (removal)! Delta: 1.879999999999983, out 71
# [local_search]: First improvement found (insertion)! Delta: 5.500000000000015, in 66
# [local_search]: First improvement found (exchange)! Delta: 5.4399999999999915, in 87, out 91
# [local_search]: First improvement found (insertion)! Delta: 0.25000000000001776, in 71
# [local_search]: No improvement found after (69) iterations!
#
# Best solution found:
# Selected elements: [56, 59, 93, 74, 26, 10, 9, 90, 69, 0, 3, 2, 6, 8, 12, 16, 18, 19, 17, 13, 28, 20, 30, 32, 35, 37, 25, 39, 41, 44, 46, 4, 45, 47, 50, 51, 53, 58, 61, 62, 48, 54, 66, 70, 72, 73, 77, 78, 80, 85, 92, 55, 49, 42, 63, 95, 97, 33, 83, 88, 79, 87, 96]
# Objective value: 1483.9999999999998
# Coverage: 100.00%
# Elapsed time: 0.13 seconds
