# %%
import math
import numpy as np
from scqbf.scqbf_instance import *
from scqbf.scqbf_evaluator import *
import random

# %%
instance = read_max_sc_qbf_instance("instances/sample_instances/1.txt")
instance
# Out:
# ScQbfInstance(n=5, subsets=[{1, 2}, {2, 3, 4}, {1, 4}, {3, 5}, {4, 5}], A=[[3.0, 1.0, -2.0, 0.0, 3.0], [0.0, -1.0, 2.0, 1.0, -1.0], [0.0, 0.0, 2.0, -2.0, 4.0], [0.0, 0.0, 0.0, 0.0, 5.0], [0.0, 0.0, 0.0, 0.0, 3.0]])

# %%
eval = ScQbfEvaluator(instance)

# %%
sample_solution = ScQbfSolution([1, 2])
eval.evaluate_coverage(sample_solution)
# Out:
# 0.8

# %%
class ScQbfGrasp:
    
    def __init__(self, instance: ScQbfInstance, iterations,
                 config: dict = {
                    "construction_method": "traditional",  # traditional | random_plus_greedy | sampled_greedy
                    "construction_args": (),
                    "local_search_method": "best_improve"  # best_improve | first_improve
                 }):
        self.instance = instance
        self.iterations = iterations
        self.config = config

        self.evaluator = ScQbfEvaluator(instance)
    
    def solve(self):
        if self.instance is None:
            raise ValueError("Problem instance is not initialized")
        
        best_sol = ScQbfSolution([])
        for i in range(self.iterations):
            constructed_sol = self._constructive_heuristic()
            print(f"Constructed solution (iteration {i}): {constructed_sol.elements}")
            
            if not self.evaluator.is_solution_valid(constructed_sol):
                print("Constructed solution is not feasible, fixing...")
                constructed_sol = self._fix_solution(constructed_sol)
            
            sol = self._local_search(constructed_sol)
            
            if (self.evaluator.evaluate_objfun(sol) > self.evaluator.evaluate_objfun(best_sol)):
                best_sol = sol
            
            
        return best_sol
    
    def _fix_solution(self, sol: ScQbfSolution) -> ScQbfSolution:
        """
        This function is called when the constructed solution is not feasible.
        It'll add the most covering elements until the solution is feasible.
        """
        while not self.evaluator.is_solution_valid(sol):
            cl = [i for i in range(self.instance.n) if i not in sol.elements]
            best_cand = None
            best_coverage = -1
            
            for cand in cl:
                coverage = self.evaluator.evaluate_insertion_delta_coverage(cand, sol)
                if coverage > best_coverage:
                    best_coverage = coverage
                    best_cand = cand
            
            if best_cand is not None:
                sol.elements.append(best_cand)
            else:
                break
        
        if not self.evaluator.is_solution_valid(sol):
            raise ValueError("Could not fix the solution to be feasible")
        
        return sol

    def _constructive_heuristic(self) -> ScQbfSolution:
        if self.config["construction_method"] == "traditional":
            alpha = self.config["construction_args"][0] if len(self.config.get("construction_args", [])) > 0 else 0.5
            return self._constructive_heuristic_traditional(alpha)

        elif self.config["construction_method"] == "random_plus_greedy":
            alpha, p = self.config["construction_args"] if len(self.config.get("construction_args", [])) > 0 else (0.5, self.instance.n // 2)
            return self._constructive_heuristic_random_plus_greedy(alpha, p)
        
        elif self.config["construction_method"] == "sampled_greedy":
            p = self.config["construction_args"][0] if len(self.config.get("construction_args", [])) > 0 else self.instance.n // 10
            return self._constructive_heuristic_sampled_greedy(p)
        
        else:
            return self._constructive_heuristic_traditional()

    def _constructive_heuristic_traditional(self, alpha: float) -> ScQbfSolution:
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            # traditional constructive heuristic
            rcl = []
            min_delta = math.inf
            max_delta = -math.inf
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun < min_delta:
                    min_delta = delta_objfun
                if delta_objfun > max_delta:
                    max_delta = delta_objfun
            
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun >= (min_delta + alpha * (max_delta - min_delta)):

                    ## ONLY add to rcl if coverage increases
                    if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0:
                        rcl.append(candidate_element)

            # Randomly select an element from the RCL to add to the solution
            if rcl:
                chosen_element = random.choice(rcl)
                constructed_sol.elements.append(chosen_element)

        return constructed_sol

    def _constructive_heuristic_random_plus_greedy(self, alpha: float, p: float):
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        # TODO make p represent percentage of the solution
        for _ in range(p):
            rcl = []
            min_delta = math.inf
            max_delta = -math.inf
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun < min_delta:
                    min_delta = delta_objfun
                if delta_objfun > max_delta:
                    max_delta = delta_objfun
            
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta_objfun >= (min_delta + alpha * (max_delta - min_delta)):

                    ## ONLY add to rcl if coverage increases
                    if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0:
                        rcl.append(candidate_element)

            # Randomly select an element from the RCL to add to the solution
            if rcl:
                chosen_element = random.choice(rcl)
                constructed_sol.elements.append(chosen_element)
            
            if not (prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)):
                break

        prev_objfun = float("-inf")

        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            
            
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            best_delta = float("-inf")
            best_cand_in = -1
            # This is where we define the RCL.
            for candidate_element in cl:
                delta_objfun = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                ## ONLY add to rcl if coverage increases
                if self.evaluator.evaluate_insertion_delta_coverage(candidate_element, constructed_sol) > 0 \
                and delta_objfun > best_delta \
                and prev_objfun < self.evaluator.evaluate_objfun(constructed_sol):
                    best_cand_in = candidate_element
                    best_delta = delta_objfun
            
            if (best_cand_in >= 0):
                constructed_sol.elements.append(best_cand_in)

        return constructed_sol
    
    def _constructive_heuristic_sampled_greedy(self, p: int):
        constructed_sol = ScQbfSolution([])
        cl = [i for i in range(self.instance.n)] # makeCl

        prev_objfun = float("-inf")
        while(prev_objfun < self.evaluator.evaluate_objfun(constructed_sol)): # Constructive Stop Criteria
            cl = [i for i in cl if i not in constructed_sol.elements] # update_cl
            prev_objfun = self.evaluator.evaluate_objfun(constructed_sol)
            
            rcl = random.sample(cl, min(len(cl), p))
            best_delta = float("-inf")
            best_cand_in = None
            for candidate_element in rcl:
                delta = self.evaluator.evaluate_insertion_delta(candidate_element, constructed_sol)
                if delta > best_delta:
                    best_delta = delta
                    best_cand_in = candidate_element
            
            if best_delta > 0 and best_cand_in is not None:
                constructed_sol.elements.append(best_cand_in)
            else:
                break
        
        return constructed_sol

    ####################

    def _local_search(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        if self.config.get("local_search_method", False) == "best_improve":
            return self._local_search_best_improve(starting_point)
        elif self.config.get("local_search_method", False) == "first_improve":
            return self._local_search_first_improve(starting_point)


    def _local_search_best_improve(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        sol = ScQbfSolution(starting_point.elements.copy())
        
        _search_iterations = 0
        
        while True:
            _search_iterations += 1
            
            best_delta = float("-inf")
            best_cand_in = None
            best_cand_out = None

            cl = [i for i in range(self.instance.n) if i not in sol.elements]

            # Evaluate insertions
            for cand_in in cl:
                delta = self.evaluator.evaluate_insertion_delta(cand_in, sol)
                if delta > best_delta:
                    best_delta = delta
                    best_cand_in = cand_in
                    best_cand_out = None

            # Evaluate removals
            for cand_out in sol.elements:
                delta = self.evaluator.evaluate_removal_delta(cand_out, sol)
                if delta > best_delta:
                    # Check if removing this element would break feasibility
                    temp_sol = ScQbfSolution(sol.elements.copy())
                    temp_sol.elements.remove(cand_out)
                    if self.evaluator.is_solution_valid(temp_sol):
                        best_delta = delta
                        best_cand_in = None
                        best_cand_out = cand_out

            # Evaluate exchanges
            for cand_in in cl:
                for cand_out in sol.elements:
                    delta = self.evaluator.evaluate_exchange_delta(cand_in, cand_out, sol)
                    if delta > best_delta:
                        # Check if this exchange would break feasibility
                        temp_sol = ScQbfSolution(sol.elements.copy())
                        temp_sol.elements.remove(cand_out)
                        temp_sol.elements.append(cand_in)
                        if self.evaluator.is_solution_valid(temp_sol):
                            best_delta = delta
                            best_cand_in = cand_in
                            best_cand_out = cand_out

            # Apply the best move if it improves the solution
            if best_delta > 0:  # Positive delta means improvement for maximization
                print(f"[local_search]: Improvement found! Delta: {best_delta}, in {best_cand_in}, out {best_cand_out}")
                if best_cand_in is not None:
                    sol.elements.append(best_cand_in)
                if best_cand_out is not None:
                    sol.elements.remove(best_cand_out)

                self.evaluator.evaluate_objfun(sol)
            else:
                print(f"[local_search]: No improvement found after ({_search_iterations}) iterations!")
                break  # No improving move found
        
        return sol

    def _local_search_first_improve(self, starting_point: ScQbfSolution) -> ScQbfSolution:
        sol = ScQbfSolution(starting_point.elements.copy())
        
        _search_iterations = 0
        
        while True:
            _search_iterations += 1
            improvement_found = False
            best_delta = 0
            best_cand_in = None
            best_cand_out = None

            cl = [i for i in range(self.instance.n) if i not in sol.elements]

            # Evaluate insertions
            for cand_in in cl:
                delta = self.evaluator.evaluate_insertion_delta(cand_in, sol)
                if delta > best_delta:
                    best_delta = delta
                    best_cand_in = cand_in
                    best_cand_out = None
                    break

            # Evaluate removals
            for cand_out in sol.elements:
                delta = self.evaluator.evaluate_removal_delta(cand_out, sol)
                if delta > best_delta:
                    # Check if removing this element would break feasibility
                    temp_sol = ScQbfSolution(sol.elements.copy())
                    temp_sol.elements.remove(cand_out)
                    if self.evaluator.is_solution_valid(temp_sol):
                        best_delta = delta
                        best_cand_in = None
                        best_cand_out = cand_out
                        break
            
            # Evaluate exchanges
            for cand_in in cl:
                for cand_out in sol.elements:
                    delta = self.evaluator.evaluate_exchange_delta(cand_in, cand_out, sol)
                    if delta > best_delta:
                        # Check if this exchange would break feasibility
                        temp_sol = ScQbfSolution(sol.elements.copy())
                        temp_sol.elements.remove(cand_out)
                        temp_sol.elements.append(cand_in)
                        if self.evaluator.is_solution_valid(temp_sol):
                            best_delta = delta
                            best_cand_in = cand_in
                            best_cand_out = cand_out
                            break
                else:
                    continue
                break

            # Apply the best move if it improves the solution
            if best_delta > 0:  # Positive delta means improvement for maximization
                print(f"[local_search]: Improvement found! Delta: {best_delta}, in {best_cand_in}, out {best_cand_out}")
                if best_cand_out is not None:
                    sol.elements.remove(best_cand_out)
                if best_cand_in is not None:
                    sol.elements.append(best_cand_in)
                self.evaluator.evaluate_objfun(sol)
            else:
                print(f"[local_search]: No improvement found after ({_search_iterations}) iterations!")
                break  # No improving move found
        
        return sol

# %%
# Test the ScQbfGrasp implementation
instance = read_max_sc_qbf_instance("instances/sample_instances/2.txt")
grasp = ScQbfGrasp(instance, iterations=10)

print("Testing GRASP algorithm...")
print(f"Instance size: n = {instance.n}")
print(f"Number of subsets: {len(instance.subsets)}")

# Run GRASP
best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print()

# Test with different alpha values
print("\nTesting different alpha values:")
alphas = [0.0, 0.3, 0.7, 1.0]
for alpha in alphas:
    grasp_test = ScQbfGrasp(instance, iterations=5, config={
        "construction_method": "traditional",
        "construction_args": (alpha,),
        "local_search_method": "best_improve"
    })
    solution = grasp_test.solve()
    obj_val = evaluator.evaluate_objfun(solution)
    coverage = evaluator.evaluate_coverage(solution)
    print(f"Alpha {alpha}: Obj={obj_val:.2f}, Coverage={coverage:.2%}, Solution={solution.elements}")
    print()
# Out:
# Testing GRASP algorithm...
# Instance size: n = 3
# Number of subsets: 3
# Constructed solution (iteration 0): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 5): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 6): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 7): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 8): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 9): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
#
# Best solution found:
# Selected elements: [2, 1, 0]
# Objective value: 7.5
# Coverage: 100.00%
#
#
# Testing different alpha values:
# Constructed solution (iteration 0): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [2, 0]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [2, 0]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [2, 0]
# [local_search]: Improvement found! Delta: 5.5, in 1, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.0: Obj=7.50, Coverage=100.00%, Solution=[2, 1, 0]
#
# Constructed solution (iteration 0): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [2, 1]
# [local_search]: Improvement found! Delta: 2.0, in 0, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.3: Obj=7.50, Coverage=100.00%, Solution=[2, 1, 0]
#
# Constructed solution (iteration 0): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 0.7: Obj=7.50, Coverage=100.00%, Solution=[1, 0, 2]
#
# Constructed solution (iteration 0): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): [1, 0]
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Alpha 1.0: Obj=7.50, Coverage=100.00%, Solution=[1, 0, 2]

# %% [markdown]
# ### Testing sampled greedy construction

# %%
instance = read_max_sc_qbf_instance("instances/sample_instances/2.txt")
grasp = ScQbfGrasp(instance, iterations=10, config={
    "construction_method": "sampled_greedy",
    "construction_args": (instance.n // 10,),
    "local_search_method": "best_improve"
}
)

best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print()
# Out:
# Constructed solution (iteration 0): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 1): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 2): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 3): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 4): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 5): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 6): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 7): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 8): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
# Constructed solution (iteration 9): []
# Constructed solution is not feasible, fixing...
# [local_search]: Improvement found! Delta: 1.5, in 2, out None
# [local_search]: No improvement found after (2) iterations!
#
# Best solution found:
# Selected elements: [0, 1, 2]
# Objective value: 7.5
# Coverage: 100.00%

# %% [markdown]
# # Testing on larger instances

# %%
instance = read_max_sc_qbf_instance("instances/gen1/instance1.txt")
grasp = ScQbfGrasp(instance, iterations=10, config={
    "construction_method": "random_plus_greedy",
    "construction_args": (),
    "local_search_method": "first_improve"
}
)

best_solution = grasp.solve()

evaluator = ScQbfEvaluator(instance)
print(f"\nBest solution found:")
print(f"Selected elements: {best_solution.elements}")
print(f"Objective value: {evaluator.evaluate_objfun(best_solution)}")
print(f"Coverage: {evaluator.evaluate_coverage(best_solution):.2%}")
print()
# Out:
# Constructed solution (iteration 0): [86, 156, 82, 117]
# 1
# [local_search]: Improvement found! Delta: 12.790000000000001, in 3, out None
# 2
# [local_search]: Improvement found! Delta: 6.209999999999999, in 13, out 117
# 3
# [local_search]: Improvement found! Delta: 10.960000000000003, in 19, out 13
# 4
# [local_search]: Improvement found! Delta: 3.5599999999999987, in 29, out 156
# 5
# [local_search]: Improvement found! Delta: 8.679999999999998, in 0, out None
# 6
# [local_search]: Improvement found! Delta: 18.470000000000002, in 32, out 0
# 7
# [local_search]: Improvement found! Delta: 15.089999999999998, in 0, out None
# 8
# [local_search]: Improvement found! Delta: 18.460000000000008, in 162, out 0
# 9
# [local_search]: Improvement found! Delta: 19.849999999999994, in 0, out None
# 10
# [local_search]: Improvement found! Delta: 15.100000000000001, in 1, out None
# 11
# [local_search]: Improvement found! Delta: 27.500000000000004, in 6, out None
# 12
# [local_search]: Improvement found! Delta: 14.759999999999998, in 79, out 1
# 13
# [local_search]: Improvement found! Delta: 16.509999999999998, in 183, out 29
# 14
# [local_search]: Improvement found! Delta: 10.689999999999987, in 144, out 82
# 15
# [local_search]: Improvement found! Delta: 17.199999999999996, in 61, out 0
# 16
# [local_search]: Improvement found! Delta: 17.96, in 0, out None
# 17
# [local_search]: Improvement found! Delta: 9.459999999999994, in 39, out 0
# 18
# [local_search]: Improvement found! Delta: 26.82, in 0, out None
# 19
# [local_search]: Improvement found! Delta: 7.610000000000008, in 156, out 0
# 20
# [local_search]: Improvement found! Delta: 25.990000000000002, in 0, out None
# 21
# [local_search]: Improvement found! Delta: 13.730000000000004, in 7, out None
# 22
# [local_search]: Improvement found! Delta: 8.069999999999997, in 28, out 7
# 23
# [local_search]: Improvement found! Delta: 9.709999999999994, in 48, out 61
# 24
# [local_search]: Improvement found! Delta: 9.069999999999999, in 41, out 19
# 25
# [local_search]: Improvement found! Delta: 15.219999999999988, in 175, out 156
# 26
# [local_search]: Improvement found! Delta: 4.88, in 177, out 162
# 27
# [local_search]: Improvement found! Delta: 10.189999999999996, in 19, out 6
# 28
# [local_search]: Improvement found! Delta: 16.83000000000001, in 112, out 19
# 29
# [local_search]: Improvement found! Delta: 11.29, in 4, out None
# 30
# [local_search]: Improvement found! Delta: 25.15, in 12, out 4
# 31
# [local_search]: Improvement found! Delta: 2.969999999999998, in 145, out 41
# 32
# [local_search]: Improvement found! Delta: 14.740000000000002, in 1, out None
# 33
# [local_search]: Improvement found! Delta: 6.390000000000002, in 19, out 183
# 34
# [local_search]: Improvement found! Delta: 6.959999999999999, in 29, out 1
# 35
# [local_search]: Improvement found! Delta: 23.520000000000003, in 1, out None
# 36
# [local_search]: Improvement found! Delta: 17.75, in 43, out 1
# 37
# [local_search]: Improvement found! Delta: 17.980000000000004, in 1, out None
# 38
# [local_search]: Improvement found! Delta: 9.279999999999994, in 27, out 1
# 39
# [local_search]: Improvement found! Delta: 21.459999999999997, in 133, out 27
# 40
# [local_search]: Improvement found! Delta: 24.950000000000003, in 1, out None
# 41
# [local_search]: Improvement found! Delta: 17.44000000000001, in 69, out 43
# 42
# [local_search]: Improvement found! Delta: 19.84, in 6, out None
# 43
# [local_search]: Improvement found! Delta: 38.720000000000006, in 11, out None
# 44
# [local_search]: Improvement found! Delta: 11.440000000000001, in 38, out 144
# 45
# [local_search]: Improvement found! Delta: 25.15999999999999, in 65, out 29
# 46
# [local_search]: Improvement found! Delta: 23.150000000000006, in 160, out 65
# 47
# [local_search]: Improvement found! Delta: 12.979999999999986, in 83, out 0
# 48
# [local_search]: Improvement found! Delta: 28.870000000000015, in 0, out None
# 49
# [local_search]: Improvement found! Delta: 0.8099999999999878, in 65, out 1
# 50
# [local_search]: Improvement found! Delta: 44.47, in 1, out None
# 51
# [local_search]: Improvement found! Delta: 21.910000000000007, in 5, out None
# 52
# [local_search]: Improvement found! Delta: 11.899999999999984, in 82, out 0
# 53
# [local_search]: Improvement found! Delta: 35.589999999999996, in 92, out 5
# 54
# [local_search]: Improvement found! Delta: 44.100000000000016, in 0, out None
# 55
# [local_search]: Improvement found! Delta: 27.090000000000007, in 5, out None
# 56
# [local_search]: Improvement found! Delta: 8.489999999999993, in 71, out 65
# 57
# [local_search]: Improvement found! Delta: 11.709999999999994, in 65, out 5
# 58
# [local_search]: Improvement found! Delta: 7.460000000000004, in 124, out 65
# 59
# [local_search]: Improvement found! Delta: 3.199999999999993, in 109, out 71
# 60
# [local_search]: Improvement found! Delta: 31.83000000000001, in 5, out None
# 61
# [local_search]: Improvement found! Delta: 4.88, in 65, out 5
# 62
# [local_search]: Improvement found! Delta: 29.04000000000001, in 5, out None
# 63
# [local_search]: Improvement found! Delta: 5.089999999999983, in 41, out 5
# 64
# [local_search]: Improvement found! Delta: 31.71000000000002, in 189, out 41
# 65
# [local_search]: Improvement found! Delta: 20.70000000000001, in 5, out None
# 66
# [local_search]: Improvement found! Delta: 14.129999999999981, in 41, out 5
# 67
# [local_search]: Improvement found! Delta: 26.520000000000003, in 150, out 41
# 68
# [local_search]: Improvement found! Delta: 29.01000000000001, in 5, out None
# 69
# [local_search]: Improvement found! Delta: 21.77, in 25, out None
# 70
# [local_search]: Improvement found! Delta: 7.929999999999993, in 41, out 25
# 71
# [local_search]: Improvement found! Delta: 14.549999999999999, in 59, out 5
# 72
# [local_search]: Improvement found! Delta: 33.41000000000001, in 5, out None
# 73
# [local_search]: Improvement found! Delta: 10.109999999999998, in 71, out 41
# 74
# [local_search]: Improvement found! Delta: 38.1, in 25, out None
# 75
# [local_search]: Improvement found! Delta: 2.279999999999991, in 37, out 5
# 76
# [local_search]: Improvement found! Delta: 31.66, in 5, out None
# 77
# [local_search]: Improvement found! Delta: 3.8700000000000045, in 75, out 5
# 78
# [local_search]: Improvement found! Delta: 22.36, in 5, out None
# 79
# [local_search]: Improvement found! Delta: 16.209999999999997, in 94, out 5
# 80
# [local_search]: Improvement found! Delta: 25.02, in 5, out None
# 81
# [local_search]: Improvement found! Delta: 23.88000000000001, in 105, out 37
# 82
# [local_search]: Improvement found! Delta: 13.400000000000016, in 137, out 75
# 83
# [local_search]: Improvement found! Delta: 15.140000000000008, in 171, out 25
# 84
# [local_search]: Improvement found! Delta: 7.249999999999989, in 148, out 59
# 85
# [local_search]: Improvement found! Delta: 6.489999999999996, in 23, out None
# 86
# [local_search]: Improvement found! Delta: 26.620000000000005, in 25, out 23
# 87
# [local_search]: Improvement found! Delta: 11.209999999999983, in 110, out 5
# 88
# [local_search]: Improvement found! Delta: 32.09000000000002, in 5, out None
# 89
# [local_search]: Improvement found! Delta: 18.899999999999995, in 23, out None
# 90
# [local_search]: Improvement found! Delta: 16.18, in 59, out 23
# 91
# [local_search]: Improvement found! Delta: 27.55999999999999, in 23, out None
# 92
# [local_search]: Improvement found! Delta: 12.660000000000018, in 99, out 23
# 93
# [local_search]: Improvement found! Delta: 35.51, in 23, out None
# 94
# [local_search]: Improvement found! Delta: 3.0199999999999987, in 116, out 94
# 95
# [local_search]: Improvement found! Delta: 9.309999999999995, in 68, out 23
# 96
# [local_search]: Improvement found! Delta: 36.48, in 23, out None
# 97
# [local_search]: Improvement found! Delta: 23.319999999999975, in 179, out 105
# 98
# [local_search]: Improvement found! Delta: 20.64999999999999, in 27, out None
# 99
# [local_search]: Improvement found! Delta: 15.700000000000003, in 37, out 27
# 100
# [local_search]: Improvement found! Delta: 22.450000000000003, in 178, out 23
# 101
# [local_search]: Improvement found! Delta: 10.490000000000013, in 195, out 3
# 102
# [local_search]: Improvement found! Delta: 50.399999999999984, in 3, out None
# 103
# [local_search]: Improvement found! Delta: 13.250000000000009, in 7, out None
# 104
# [local_search]: Improvement found! Delta: 42.56, in 119, out 7
# 105
# [local_search]: Improvement found! Delta: 10.699999999999967, in 158, out 109
# 106
# [local_search]: Improvement found! Delta: 5.850000000000026, in 98, out 82
# 107
# [local_search]: Improvement found! Delta: 7.629999999999989, in 47, out 19
# 108
# [local_search]: Improvement found! Delta: 21.320000000000032, in 166, out 86
# 109
# [local_search]: Improvement found! Delta: 19.910000000000004, in 91, out 3
# 110
# [local_search]: Improvement found! Delta: 43.55999999999998, in 3, out None
# 111
# [local_search]: Improvement found! Delta: 18.649999999999995, in 7, out None
# 112
# [local_search]: Improvement found! Delta: 15.239999999999995, in 14, out 1
# 113
# [local_search]: Improvement found! Delta: 36.89, in 1, out None
# 114
# [local_search]: Improvement found! Delta: 12.629999999999995, in 46, out 7
# 115
# [local_search]: Improvement found! Delta: 28.320000000000036, in 67, out 3
# 116
# [local_search]: Improvement found! Delta: 34.52, in 126, out 1
# 117
# [local_search]: Improvement found! Delta: 35.63999999999999, in 1, out None
# 118
# [local_search]: Improvement found! Delta: 25.019999999999957, in 3, out None
# 119
# [local_search]: Improvement found! Delta: 23.660000000000004, in 54, out 1
# 120
# [local_search]: Improvement found! Delta: 21.83000000000004, in 161, out 3
# 121
# [local_search]: Improvement found! Delta: 21.25999999999999, in 1, out None
# 122
# [local_search]: Improvement found! Delta: 33.26, in 105, out 1
# 123
# [local_search]: Improvement found! Delta: 24.48999999999999, in 1, out None
# 124
# [local_search]: Improvement found! Delta: 25.700000000000014, in 78, out 1
# 125
# [local_search]: Improvement found! Delta: 21.38999999999999, in 1, out None
# 126
# [local_search]: Improvement found! Delta: 30.69999999999996, in 3, out None
# 127
# [local_search]: Improvement found! Delta: 7.4000000000000155, in 9, out 1
# 128
# [local_search]: Improvement found! Delta: 17.15000000000005, in 85, out 3
# 129
# [local_search]: Improvement found! Delta: 22.970000000000002, in 147, out 46
# 130
# [local_search]: Improvement found! Delta: 20.71999999999999, in 1, out None
# 131
# [local_search]: Improvement found! Delta: 13.290000000000006, in 27, out 1
# 132
# [local_search]: Improvement found! Delta: 23.07999999999999, in 1, out None
# 133
# [local_search]: Improvement found! Delta: 15.060000000000006, in 36, out 1
# 134
# [local_search]: Improvement found! Delta: 16.910000000000007, in 123, out 179
# 135
# [local_search]: Improvement found! Delta: 7.460000000000009, in 42, out 36
# 136
# [local_search]: Improvement found! Delta: 1.9299999999999473, in 113, out 0
# 137
# [local_search]: Improvement found! Delta: 46.07000000000002, in 0, out None
# 138
# [local_search]: Improvement found! Delta: 6.039999999999983, in 36, out 137
# 139
# [local_search]: Improvement found! Delta: 3.3000000000000114, in 137, out 27
# 140
# [local_search]: Improvement found! Delta: 7.7600000000000176, in 142, out 36
# 141
# [local_search]: Improvement found! Delta: 8.08999999999999, in 1, out None
# 142
# [local_search]: Improvement found! Delta: 23.15, in 27, out 1
# 143
# [local_search]: Improvement found! Delta: 10.86, in 163, out 27
# 144
# [local_search]: Improvement found! Delta: 14.54999999999999, in 1, out None
# 145
# [local_search]: Improvement found! Delta: 21.9, in 27, out 1
# 146
# [local_search]: Improvement found! Delta: 16.90999999999999, in 1, out None
# 147
# [local_search]: Improvement found! Delta: 27.85999999999999, in 36, out 1
# 148
# [local_search]: Improvement found! Delta: 8.390000000000004, in 80, out 142
# 149
# [local_search]: Improvement found! Delta: 9.329999999999988, in 144, out 137
# 150
# [local_search]: Improvement found! Delta: 4.509999999999979, in 142, out 0
# 151
# [local_search]: Improvement found! Delta: 35.440000000000026, in 0, out None
# 152
# [local_search]: Improvement found! Delta: 12.129999999999999, in 43, out 42
# 153
# [local_search]: Improvement found! Delta: 23.75999999999998, in 3, out None
# 154
# [local_search]: Improvement found! Delta: 13.180000000000023, in 42, out 3
# 155
# [local_search]: Improvement found! Delta: 19.08999999999998, in 3, out None
# 156
# [local_search]: Improvement found! Delta: 19.32000000000002, in 46, out 3
# 157
# [local_search]: Improvement found! Delta: 21.489999999999966, in 159, out 0
# 158
# [local_search]: Improvement found! Delta: 24.090000000000025, in 0, out None
# 159
# [local_search]: Improvement found! Delta: 20.269999999999975, in 137, out 0
# 160
# [local_search]: Improvement found! Delta: 26.950000000000024, in 0, out None
# 161
# [local_search]: Improvement found! Delta: 31.959999999999976, in 172, out 0
# 162
# [local_search]: Improvement found! Delta: 22.640000000000025, in 0, out None
# 163
# [local_search]: Improvement found! Delta: 32.619999999999976, in 168, out 0
# 164
# [local_search]: Improvement found! Delta: 25.420000000000027, in 0, out None
# 165
# [local_search]: Improvement found! Delta: 26.419999999999984, in 3, out None
# 166
# [local_search]: Improvement found! Delta: 25.549999999999997, in 132, out 42
# 167
# [local_search]: Improvement found! Delta: 8.130000000000022, in 42, out 3
# 168
# [local_search]: Improvement found! Delta: 30.98999999999998, in 3, out None
# 169
# [local_search]: Improvement found! Delta: 5.389999999999954, in 86, out 0
# 170
# [local_search]: Improvement found! Delta: 34.65000000000002, in 0, out None
# 171
# [local_search]: Improvement found! Delta: 11.520000000000032, in 127, out 6
# 172
# [local_search]: Improvement found! Delta: 11.260000000000009, in 6, out 86
# 173
# [local_search]: Improvement found! Delta: 12.940000000000005, in 17, out None
# 174
# [local_search]: Improvement found! Delta: 20.699999999999985, in 49, out 17
# 175
# [local_search]: Improvement found! Delta: 6.869999999999989, in 72, out 159
# 176
# [local_search]: Improvement found! Delta: 5.680000000000003, in 114, out 59
# 177
# [local_search]: Improvement found! Delta: 0.750000000000008, in 13, out None
# 178
# [local_search]: Improvement found! Delta: 33.47, in 40, out 13
# 179
# [local_search]: Improvement found! Delta: 9.359999999999987, in 59, out 40
# 180
# [local_search]: Improvement found! Delta: 32.0, in 40, out None
# 181
# [local_search]: Improvement found! Delta: 12.989999999999997, in 41, out None
# 182
# [local_search]: Improvement found! Delta: 12.81000000000001, in 76, out 41
# 183
# [local_search]: Improvement found! Delta: 17.489999999999995, in 41, out None
# 184
# [local_search]: Improvement found! Delta: 16.03999999999998, in 86, out 41
# 185
# [local_search]: Improvement found! Delta: 14.77, in 159, out 40
# 186
# [local_search]: Improvement found! Delta: 11.170000000000009, in 13, out None
# 187
# [local_search]: Improvement found! Delta: 15.829999999999997, in 40, out 13
# 188
# [local_search]: Improvement found! Delta: 3.839999999999991, in 97, out 40
# 189
# [local_search]: Improvement found! Delta: 3.440000000000025, in 167, out 76
# 190
# [local_search]: Improvement found! Delta: 7.439999999999998, in 1, out None
# 191
# [local_search]: Improvement found! Delta: 14.480000000000006, in 22, out 1
# 192
# [local_search]: Improvement found! Delta: 11.959999999999978, in 192, out 42
# 193
# [local_search]: Improvement found! Delta: 6.300000000000022, in 153, out 6
# 194
# [local_search]: Improvement found! Delta: 28.949999999999985, in 6, out None
# 195
# [local_search]: Improvement found! Delta: 9.399999999999988, in 102, out 6
# 196
# [local_search]: Improvement found! Delta: 25.100000000000016, in 179, out 49
# 197
# [local_search]: Improvement found! Delta: 20.77, in 184, out 3
# 198
# [local_search]: Improvement found! Delta: 25.269999999999996, in 3, out None
# 199
# [local_search]: Improvement found! Delta: 5.740000000000006, in 94, out 72
# 200
# [local_search]: Improvement found! Delta: 4.349999999999996, in 41, out 3
# 201
# [local_search]: Improvement found! Delta: 2.479999999999988, in 169, out 0
# 202
# [local_search]: Improvement found! Delta: 24.66000000000001, in 0, out None
# 203
# [local_search]: Improvement found! Delta: 7.7099999999999955, in 1, out None
# 204
# [local_search]: Improvement found! Delta: 21.909999999999982, in 3, out None
# 205
# [local_search]: Improvement found! Delta: 9.390000000000008, in 52, out 1
# 206
# [local_search]: Improvement found! Delta: 6.579999999999991, in 72, out 52
# 207
# [local_search]: Improvement found! Delta: 7.610000000000006, in 73, out 59
# 208
# [local_search]: Improvement found! Delta: 2.8000000000000105, in 52, out 41
# 209
# [local_search]: Improvement found! Delta: 8.070000000000007, in 13, out None
# 210
# [local_search]: Improvement found! Delta: 11.679999999999986, in 41, out 13
# 211
# [local_search]: Improvement found! Delta: 8.710000000000008, in 13, out None
# 212
# [local_search]: Improvement found! Delta: 20.199999999999992, in 15, out None
# 213
# [local_search]: Improvement found! Delta: 11.399999999999991, in 59, out 13
# 214
# [local_search]: Improvement found! Delta: 4.110000000000011, in 174, out 59
# 215
# [local_search]: Improvement found! Delta: 15.010000000000009, in 13, out None
# 216
# [local_search]: Improvement found! Delta: 9.430000000000009, in 17, out None
# 217
# [local_search]: Improvement found! Delta: 2.5999999999999917, in 40, out 17
# 218
# [local_search]: Improvement found! Delta: 2.0899999999999928, in 49, out 73
# 219
# [local_search]: Improvement found! Delta: 9.54, in 53, out 169
# 220
# [local_search]: Improvement found! Delta: 13.110000000000007, in 154, out 52
# 221
# [local_search]: Improvement found! Delta: 9.279999999999998, in 1, out None
# 222
# [local_search]: Improvement found! Delta: 10.439999999999994, in 81, out 1
# 223
# [local_search]: Improvement found! Delta: 9.849999999999998, in 1, out None
# 224
# [local_search]: Improvement found! Delta: 6.950000000000004, in 87, out 1
# 225
# [local_search]: Improvement found! Delta: 5.539999999999998, in 1, out None
# 226
# [local_search]: Improvement found! Delta: 3.6500000000000083, in 50, out 1
# 227
# [local_search]: Improvement found! Delta: 9.999999999999998, in 52, out 50
# 228
# [local_search]: Improvement found! Delta: 1.8199999999999896, in 136, out 52
# 229
# [local_search]: Improvement found! Delta: 10.540000000000017, in 146, out 81
# 230
# [local_search]: Improvement found! Delta: 16.06, in 1, out None
# 231
# [local_search]: Improvement found! Delta: 0.7700000000000151, in 44, out 87
# 232
# [local_search]: Improvement found! Delta: 2.710000000000008, in 17, out 3
# 233
# [local_search]: Improvement found! Delta: 16.690000000000005, in 81, out 49
# 234
# [local_search]: Improvement found! Delta: 5.149999999999983, in 111, out 44
# 235
# [local_search]: Improvement found! Delta: 8.36999999999999, in 95, out 40
# 236
# [local_search]: Improvement found! Delta: 26.299999999999997, in 40, out None
# 237
# [local_search]: Improvement found! Delta: 14.290000000000001, in 42, out None
# 238
# [local_search]: Improvement found! Delta: 11.859999999999985, in 125, out 42
# 239
# [local_search]: Improvement found! Delta: 15.82, in 42, out None
# 240
# [local_search]: Improvement found! Delta: 6.690000000000022, in 44, out 42
# 241
# [local_search]: Improvement found! Delta: 8.52, in 42, out None
# 242
# [local_search]: Improvement found! Delta: 6.049999999999983, in 49, out 42
# 243
# [local_search]: Improvement found! Delta: 3.0800000000000085, in 84, out 49
# 244
# [local_search]: Improvement found! Delta: 18.489999999999995, in 173, out 13
# 245
# [local_search]: Improvement found! Delta: 18.840000000000003, in 13, out None
# 246
# [local_search]: Improvement found! Delta: 1.690000000000007, in 24, out None
# 247
# [local_search]: Improvement found! Delta: 14.02999999999998, in 49, out 24
# 248
# [local_search]: Improvement found! Delta: 6.000000000000006, in 24, out None
# 249
# [local_search]: Improvement found! Delta: 11.369999999999987, in 89, out 24
# 250
# [local_search]: Improvement found! Delta: 6.150000000000016, in 157, out 49
# 251
# [local_search]: Improvement found! Delta: 8.100000000000007, in 24, out None
# 252
# [local_search]: Improvement found! Delta: 10.649999999999988, in 115, out 24
# 253
# [local_search]: Improvement found! Delta: 4.95000000000001, in 16, out None
# 254
# [local_search]: Improvement found! Delta: 9.559999999999977, in 49, out 16
# 255
# [local_search]: Improvement found! Delta: 8.45000000000001, in 16, out None
# 256
# [local_search]: Improvement found! Delta: 2.9999999999999876, in 118, out 16
# 257
# [local_search]: Improvement found! Delta: 3.4499999999999913, in 164, out 17
# 258
# [local_search]: Improvement found! Delta: 9.759999999999968, in 128, out 95
# 259
# [local_search]: Improvement found! Delta: 12.869999999999987, in 129, out 81
# 260
# [local_search]: Improvement found! Delta: 9.189999999999987, in 63, out 84
# 261
# [local_search]: Improvement found! Delta: 15.840000000000002, in 81, out None
# 262
# [local_search]: Improvement found! Delta: 4.040000000000012, in 4, out None
# 263
# [local_search]: Improvement found! Delta: 12.08999999999998, in 84, out 4
# 264
# [local_search]: Improvement found! Delta: 1.1899999999999897, in 131, out 81
# 265
# [local_search]: Improvement found! Delta: 4.770000000000042, in 10, out None
# 266
# [local_search]: Improvement found! Delta: 8.439999999999994, in 35, out None
# 267
# [local_search]: Improvement found! Delta: 7.729999999999961, in 176, out 10
# 268
# [local_search]: Improvement found! Delta: 5.8400000000000105, in 81, out 131
# 269
# [local_search]: Improvement found! Delta: 3.9900000000000078, in 87, out 35
# 270
# [local_search]: Improvement found! Delta: 7.490000000000012, in 90, out 84
# 271
# [local_search]: Improvement found! Delta: 6.110000000000042, in 10, out None
# 272
# [local_search]: Improvement found! Delta: 5.669999999999972, in 50, out 10
# 273
# [local_search]: Improvement found! Delta: 7.939999999999993, in 23, out None
# 274
# [local_search]: Improvement found! Delta: 16.550000000000004, in 59, out None
# 275
# [local_search]: Improvement found! Delta: 10.450000000000005, in 76, out None
# 276
# [local_search]: Improvement found! Delta: 3.9700000000000153, in 60, out 63
# 277
# [local_search]: Improvement found! Delta: 8.459999999999996, in 131, out 164
# 278
# [local_search]: Improvement found! Delta: 10.940000000000014, in 139, out 83
# 279
# [local_search]: Improvement found! Delta: 3.100000000000067, in 10, out 60
# 280
# [local_search]: Improvement found! Delta: 5.109999999999945, in 169, out 10
# 281
# [local_search]: Improvement found! Delta: 13.110000000000039, in 187, out 39
# 282
# [local_search]: Improvement found! Delta: 12.260000000000002, in 16, out None
# 283
# [local_search]: Improvement found! Delta: 11.44999999999998, in 39, out 118
# 284
# [local_search]: Improvement found! Delta: 2.7999999999999936, in 118, out 16
# 285
# [local_search]: Improvement found! Delta: 2.1900000000000523, in 10, out None
# 286
# [local_search]: Improvement found! Delta: 2.3899999999999513, in 16, out 10
# 287
# [local_search]: Improvement found! Delta: 4.010000000000004, in 135, out None
# 288
# [local_search]: Improvement found! Delta: 6.400000000000004, in 83, out 39
# 289
# [local_search]: Improvement found! Delta: 6.500000000000023, in 196, out 195
# 290
# [local_search]: Improvement found! Delta: 12.289999999999969, in 3, out None
# 291
# [local_search]: Improvement found! Delta: 10.88, in 60, out None
# 292
# [local_search]: Improvement found! Delta: 0.6399999999999899, in 74, out 184
# 293
# [local_search]: Improvement found! Delta: 6.679999999999997, in 182, out 13
# 294
# [local_search]: Improvement found! Delta: 5.240000000000011, in 13, out 74
# 295
# [local_search]: Improvement found! Delta: 5.440000000000001, in 197, out 13
# 296
# [local_search]: Improvement found! Delta: 3.010000000000008, in 109, out 176
# 297
# [local_search]: Improvement found! Delta: 1.180000000000022, in 176, out None
# 298
# [local_search]: No improvement found after (298) iterations!
# Constructed solution (iteration 1): [162, 59, 25, 114, 173, 177]
# 1
# [local_search]: Improvement found! Delta: 16.26, in 0, out 114
# 2
# [local_search]: Improvement found! Delta: 20.379999999999995, in 12, out 0
# 3
# [local_search]: Improvement found! Delta: 7.899999999999998, in 1, out 177
# 4
# [local_search]: Improvement found! Delta: 6.169999999999995, in 30, out 162
# 5
# [local_search]: Improvement found! Delta: 9.919999999999991, in 37, out 173
# 6
# [local_search]: Improvement found! Delta: 1.8200000000000007, in 3, out None
# 7
# [local_search]: Improvement found! Delta: 24.1, in 9, out 3
# 8
# [local_search]: Improvement found! Delta: 15.65, in 11, out None
# 9
# [local_search]: Improvement found! Delta: 3.6700000000000004, in 32, out 11
# 10
# [local_search]: Improvement found! Delta: 18.59999999999999, in 91, out 32
# 11
# [local_search]: Improvement found! Delta: 4.699999999999996, in 35, out 9
# 12
# [local_search]: Improvement found! Delta: 4.049999999999994, in 158, out 37
# 13
# [local_search]: Improvement found! Delta: 10.689999999999998, in 5, out None
# 14
# [local_search]: Improvement found! Delta: 27.23, in 37, out 5
# 15
# [local_search]: Improvement found! Delta: 7.169999999999999, in 5, out None
# 16
# [local_search]: Improvement found! Delta: 33.449999999999996, in 67, out 5
# 17
# [local_search]: Improvement found! Delta: 4.970000000000004, in 179, out 67
# 18
# [local_search]: Improvement found! Delta: 24.849999999999998, in 9, out None
# 19
# [local_search]: Improvement found! Delta: 5.1800000000000015, in 46, out 9
# 20
# [local_search]: Improvement found! Delta: 8.419999999999996, in 67, out 46
# 21
# [local_search]: Improvement found! Delta: 18.459999999999997, in 9, out None
# 22
# [local_search]: Improvement found! Delta: 18.940000000000005, in 11, out 9
# 23
# [local_search]: Improvement found! Delta: 12.829999999999998, in 157, out 11
# 24
# [local_search]: Improvement found! Delta: 16.019999999999996, in 9, out None
# 25
# [local_search]: Improvement found! Delta: 18.840000000000003, in 11, out 9
# 26
# [local_search]: Improvement found! Delta: 2.4399999999999995, in 104, out 11
# 27
# [local_search]: Improvement found! Delta: 6.820000000000002, in 119, out 104
# 28
# [local_search]: Improvement found! Delta: 25.299999999999994, in 9, out None
# 29
# [local_search]: Improvement found! Delta: 19.180000000000007, in 11, out 9
# 30
# [local_search]: Improvement found! Delta: 5.859999999999997, in 5, out None
# 31
# [local_search]: Improvement found! Delta: 27.680000000000003, in 9, out 5
# 32
# [local_search]: Improvement found! Delta: 14.300000000000004, in 92, out 9
# 33
# [local_search]: Improvement found! Delta: 4.65, in 0, out None
# 34
# [local_search]: Improvement found! Delta: 33.6, in 9, out 0
# 35
# [local_search]: Improvement found! Delta: 1.5800000000000018, in 33, out 9
# 36
# [local_search]: Improvement found! Delta: 6.37, in 0, out None
# 37
# [local_search]: Improvement found! Delta: 35.900000000000006, in 9, out 0
# 38
# [local_search]: Improvement found! Delta: 5.22, in 125, out 33
# 39
# [local_search]: Improvement found! Delta: 22.489999999999995, in 5, out None
# 40
# [local_search]: Improvement found! Delta: 10.400000000000006, in 14, out 5
# 41
# [local_search]: Improvement found! Delta: 22.419999999999995, in 5, out None
# 42
# [local_search]: Improvement found! Delta: 6.680000000000003, in 22, out 5
# 43
# [local_search]: Improvement found! Delta: 27.149999999999995, in 5, out None
# 44
# [local_search]: Improvement found! Delta: 17.339999999999996, in 32, out 22
# 45
# [local_search]: Improvement found! Delta: 16.219999999999995, in 22, out 5
# 46
# [local_search]: Improvement found! Delta: 4.35, in 48, out 22
# 47
# [local_search]: Improvement found! Delta: 20.610000000000003, in 195, out 14
# 48
# [local_search]: Improvement found! Delta: 14.180000000000001, in 0, out None
# 49
# [local_search]: Improvement found! Delta: 11.909999999999995, in 5, out 0
# 50
# [local_search]: Improvement found! Delta: 12.040000000000006, in 33, out 5
# 51
# [local_search]: Improvement found! Delta: 15.9, in 0, out None
# 52
# [local_search]: Improvement found! Delta: 20.21, in 38, out 0
# 53
# [local_search]: Improvement found! Delta: 12.910000000000005, in 105, out 38
# 54
# [local_search]: Improvement found! Delta: 18.5, in 0, out None
# 55
# [local_search]: Improvement found! Delta: 26.730000000000008, in 71, out 0
# 56
# [local_search]: Improvement found! Delta: 16.48, in 0, out None
# 57
# [local_search]: Improvement found! Delta: 8.490000000000006, in 14, out 0
# 58
# [local_search]: Improvement found! Delta: 17.229999999999993, in 85, out 14
# 59
# [local_search]: Improvement found! Delta: 18.970000000000013, in 126, out 32
# 60
# [local_search]: Improvement found! Delta: 16.22, in 0, out None
# 61
# [local_search]: Improvement found! Delta: 21.820000000000007, in 46, out 0
# 62
# [local_search]: Improvement found! Delta: 8.299999999999995, in 146, out 33
# 63
# [local_search]: Improvement found! Delta: 5.030000000000005, in 33, out 46
# 64
# [local_search]: Improvement found! Delta: 13.470000000000002, in 0, out None
# 65
# [local_search]: Improvement found! Delta: 15.249999999999993, in 5, out 0
# 66
# [local_search]: Improvement found! Delta: 14.910000000000007, in 46, out 5
# 67
# [local_search]: Improvement found! Delta: 10.369999999999985, in 142, out 33
# 68
# [local_search]: Improvement found! Delta: 45.629999999999995, in 5, out None
# 69
# [local_search]: Improvement found! Delta: 27.120000000000005, in 14, out None
# 70
# [local_search]: Improvement found! Delta: 14.219999999999988, in 16, out 14
# 71
# [local_search]: Improvement found! Delta: 21.740000000000006, in 14, out None
# 72
# [local_search]: Improvement found! Delta: 4.629999999999999, in 22, out 5
# 73
# [local_search]: Improvement found! Delta: 9.879999999999999, in 5, out 16
# 74
# [local_search]: Improvement found! Delta: 8.499999999999996, in 16, out 14
# 75
# [local_search]: Improvement found! Delta: 10.45000000000001, in 97, out 5
# 76
# [local_search]: Improvement found! Delta: 0.9000000000000015, in 0, out None
# 77
# [local_search]: Improvement found! Delta: 40.26, in 5, out 0
# 78
# [local_search]: Improvement found! Delta: 19.69, in 14, out None
# 79
# [local_search]: Improvement found! Delta: 1.4199999999999964, in 32, out 14
# 80
# [local_search]: Improvement found! Delta: 13.190000000000005, in 33, out 32
# 81
# [local_search]: Improvement found! Delta: 5.09, in 38, out 16
# 82
# [local_search]: Improvement found! Delta: 7.169999999999997, in 118, out 33
# 83
# [local_search]: Improvement found! Delta: 2.2600000000000087, in 36, out 38
# 84
# [local_search]: Improvement found! Delta: 4.379999999999987, in 47, out 22
# 85
# [local_search]: Improvement found! Delta: 15.019999999999992, in 69, out 97
# 86
# [local_search]: Improvement found! Delta: 7.859999999999994, in 14, out 35
# 87
# [local_search]: Improvement found! Delta: 8.669999999999996, in 196, out 14
# 88
# [local_search]: Improvement found! Delta: 11.160000000000018, in 147, out 36
# 89
# [local_search]: Improvement found! Delta: 10.030000000000038, in 192, out 195
# 90
# [local_search]: Improvement found! Delta: 1.2199999999999924, in 6, out None
# 91
# [local_search]: Improvement found! Delta: 42.29, in 14, out 6
# 92
# [local_search]: Improvement found! Delta: 17.760000000000005, in 7, out None
# 93
# [local_search]: Improvement found! Delta: 16.300000000000004, in 15, out 7
# 94
# [local_search]: Improvement found! Delta: 16.189999999999994, in 144, out 15
# 95
# [local_search]: Improvement found! Delta: 3.2999999999999905, in 148, out 5
# 96
# [local_search]: Improvement found! Delta: 51.53000000000001, in 5, out None
# 97
# [local_search]: Improvement found! Delta: 9.800000000000004, in 116, out 105
# 98
# [local_search]: Improvement found! Delta: 34.41, in 7, out None
# 99
# [local_search]: Improvement found! Delta: 2.1100000000000003, in 15, out 7
# 100
# [local_search]: Improvement found! Delta: 32.44, in 7, out None
# 101
# [local_search]: Improvement found! Delta: 7.2099999999999955, in 22, out 7
# 102
# [local_search]: Improvement found! Delta: 25.680000000000003, in 7, out None
# 103
# [local_search]: Improvement found! Delta: 34.58, in 10, out None
# 104
# [local_search]: Improvement found! Delta: 27.82000000000002, in 90, out 22
# 105
# [local_search]: Improvement found! Delta: 17.669999999999998, in 13, out None
# 106
# [local_search]: Improvement found! Delta: 7.599999999999998, in 22, out 10
# 107
# [local_search]: Improvement found! Delta: 38.76, in 10, out None
# 108
# [local_search]: Improvement found! Delta: 7.760000000000009, in 39, out 13
# 109
# [local_search]: Improvement found! Delta: 32.239999999999995, in 13, out None
# 110
# [local_search]: Improvement found! Delta: 8.459999999999997, in 50, out 10
# 111
# [local_search]: Improvement found! Delta: 38.57, in 10, out None
# 112
# [local_search]: Improvement found! Delta: 8.460000000000004, in 105, out 1
# 113
# [local_search]: Improvement found! Delta: 50.22999999999999, in 1, out None
# 114
# [local_search]: Improvement found! Delta: 9.849999999999987, in 154, out 22
# 115
# [local_search]: Improvement found! Delta: 13.430000000000017, in 22, out 10
# 116
# [local_search]: Improvement found! Delta: 4.199999999999992, in 6, out None
# 117
# [local_search]: Improvement found! Delta: 24.18000000000001, in 10, out 6
# 118
# [local_search]: Improvement found! Delta: 12.759999999999968, in 36, out 22
# 119
# [local_search]: Improvement found! Delta: 3.8800000000000003, in 43, out 13
# 120
# [local_search]: Improvement found! Delta: 34.209999999999994, in 13, out None
# 121
# [local_search]: Improvement found! Delta: 9.500000000000005, in 40, out 13
# 122
# [local_search]: Improvement found! Delta: 6.54, in 115, out 7
# 123
# [local_search]: Improvement found! Delta: 40.61, in 7, out None
# 124
# [local_search]: Improvement found! Delta: 9.090000000000007, in 89, out 7
# 125
# [local_search]: Improvement found! Delta: 35.2, in 7, out None
# 126
# [local_search]: Improvement found! Delta: 9.64, in 27, out 7
# 127
# [local_search]: Improvement found! Delta: 30.310000000000002, in 7, out None
# 128
# [local_search]: Improvement found! Delta: 8.84000000000001, in 28, out 7
# 129
# [local_search]: Improvement found! Delta: 25.990000000000002, in 7, out None
# 130
# [local_search]: Improvement found! Delta: 2.3999999999999897, in 53, out 7
# 131
# [local_search]: Improvement found! Delta: 19.32, in 7, out None
# 132
# [local_search]: Improvement found! Delta: 18.370000000000005, in 72, out 7
# 133
# [local_search]: Improvement found! Delta: 14.210000000000012, in 114, out 53
# 134
# [local_search]: Improvement found! Delta: 18.339999999999996, in 123, out 10
# 135
# [local_search]: Improvement found! Delta: 11.429999999999996, in 174, out 39
# 136
# [local_search]: Improvement found! Delta: 29.650000000000006, in 10, out None
# 137
# [local_search]: Improvement found! Delta: 6.579999999999982, in 33, out 50
# 138
# [local_search]: Improvement found! Delta: 8.51, in 13, out None
# 139
# [local_search]: Improvement found! Delta: 22.290000000000006, in 18, out 13
# 140
# [local_search]: Improvement found! Delta: 16.950000000000014, in 197, out 18
# 141
# [local_search]: Improvement found! Delta: 1.0799999999999965, in 7, out None
# 142
# [local_search]: Improvement found! Delta: 32.61000000000001, in 18, out 7
# 143
# [local_search]: Improvement found! Delta: 2.9799999999999915, in 41, out 18
# 144
# [local_search]: Improvement found! Delta: 11.240000000000004, in 159, out 33
# 145
# [local_search]: Improvement found! Delta: 9.52999999999999, in 65, out 10
# 146
# [local_search]: Improvement found! Delta: 36.41000000000001, in 10, out None
# 147
# [local_search]: Improvement found! Delta: 1.0399999999999903, in 39, out 10
# 148
# [local_search]: Improvement found! Delta: 4.969999999999993, in 150, out 39
# 149
# [local_search]: Improvement found! Delta: 34.750000000000014, in 10, out None
# 150
# [local_search]: Improvement found! Delta: 7.049999999999989, in 87, out 10
# 151
# [local_search]: Improvement found! Delta: 36.22000000000001, in 10, out None
# 152
# [local_search]: Improvement found! Delta: 26.75000000000001, in 22, out None
# 153
# [local_search]: Improvement found! Delta: 3.849999999999976, in 38, out 22
# 154
# [local_search]: Improvement found! Delta: 1.3900000000000134, in 39, out 38
# 155
# [local_search]: Improvement found! Delta: 10.189999999999998, in 76, out 87
# 156
# [local_search]: Improvement found! Delta: 10.680000000000003, in 129, out 150
# 157
# [local_search]: Improvement found! Delta: 16.489999999999995, in 7, out None
# 158
# [local_search]: Improvement found! Delta: 16.879999999999992, in 38, out 7
# 159
# [local_search]: Improvement found! Delta: 12.179999999999996, in 7, out None
# 160
# [local_search]: Improvement found! Delta: 21.510000000000005, in 32, out 7
# 161
# [local_search]: Improvement found! Delta: 6.21, in 87, out 32
# 162
# [local_search]: Improvement found! Delta: 12.439999999999984, in 150, out 115
# 163
# [local_search]: Improvement found! Delta: 8.629999999999992, in 112, out 39
# 164
# [local_search]: Improvement found! Delta: 29.45999999999999, in 178, out 10
# 165
# [local_search]: Improvement found! Delta: 29.820000000000014, in 189, out 43
# 166
# [local_search]: Improvement found! Delta: 15.740000000000014, in 10, out None
# 167
# [local_search]: Improvement found! Delta: 11.839999999999987, in 22, out 10
# 168
# [local_search]: Improvement found! Delta: 19.409999999999986, in 43, out 22
# 169
# [local_search]: Improvement found! Delta: 21.230000000000018, in 10, out None
# 170
# [local_search]: Improvement found! Delta: 24.029999999999987, in 172, out 10
# 171
# [local_search]: Improvement found! Delta: 17.15000000000002, in 10, out None
# 172
# [local_search]: Improvement found! Delta: 30.439999999999976, in 173, out 10
# 173
# [local_search]: Improvement found! Delta: 14.18000000000002, in 10, out None
# 174
# [local_search]: Improvement found! Delta: 22.749999999999975, in 63, out 10
# 175
# [local_search]: Improvement found! Delta: 13.419999999999972, in 113, out 30
# 176
# [local_search]: Improvement found! Delta: 8.780000000000026, in 187, out 1
# 177
# [local_search]: Improvement found! Delta: 47.129999999999974, in 1, out None
# 178
# [local_search]: Improvement found! Delta: 12.800000000000002, in 10, out None
# 179
# [local_search]: Improvement found! Delta: 37.28999999999998, in 50, out 10
# 180
# [local_search]: Improvement found! Delta: 6.050000000000042, in 22, out 1
# 181
# [local_search]: Improvement found! Delta: 29.269999999999975, in 1, out None
# 182
# [local_search]: Improvement found! Delta: 4.080000000000014, in 60, out 89
# 183
# [local_search]: Improvement found! Delta: 10.770000000000016, in 33, out 1
# 184
# [local_search]: Improvement found! Delta: 19.829999999999973, in 1, out None
# 185
# [local_search]: Improvement found! Delta: 7.39000000000004, in 44, out 1
# 186
# [local_search]: Improvement found! Delta: 21.169999999999973, in 1, out None
# 187
# [local_search]: Improvement found! Delta: 21.220000000000024, in 80, out 1
# 188
# [local_search]: Improvement found! Delta: 16.25, in 97, out 33
# 189
# [local_search]: Improvement found! Delta: 30.959999999999997, in 98, out 44
# 190
# [local_search]: Improvement found! Delta: 13.989999999999977, in 1, out None
# 191
# [local_search]: Improvement found! Delta: 10.250000000000009, in 30, out 1
# 192
# [local_search]: Improvement found! Delta: 26.970000000000013, in 166, out 30
# 193
# [local_search]: Improvement found! Delta: 8.429999999999959, in 99, out 144
# 194
# [local_search]: Improvement found! Delta: 10.990000000000013, in 110, out 41
# 195
# [local_search]: Improvement found! Delta: 8.729999999999999, in 34, out 22
# 196
# [local_search]: Improvement found! Delta: 19.509999999999998, in 171, out 173
# 197
# [local_search]: Improvement found! Delta: 9.269999999999994, in 1, out None
# 198
# [local_search]: Improvement found! Delta: 21.200000000000006, in 22, out 1
# 199
# [local_search]: Improvement found! Delta: 7.859999999999987, in 89, out 22
# 200
# [local_search]: Improvement found! Delta: 16.65, in 163, out 89
# 201
# [local_search]: Improvement found! Delta: 15.729999999999993, in 1, out None
# 202
# [local_search]: Improvement found! Delta: 18.35000000000001, in 22, out 1
# 203
# [local_search]: Improvement found! Delta: 7.2699999999999925, in 33, out 22
# 204
# [local_search]: Improvement found! Delta: 15.719999999999992, in 1, out None
# 205
# [local_search]: Improvement found! Delta: 21.77000000000001, in 22, out 1
# 206
# [local_search]: Improvement found! Delta: 16.08, in 173, out 22
# 207
# [local_search]: Improvement found! Delta: 25.379999999999992, in 1, out None
# 208
# [local_search]: Improvement found! Delta: 6.320000000000013, in 22, out 1
# 209
# [local_search]: Improvement found! Delta: 15.97999999999999, in 1, out None
# 210
# [local_search]: Improvement found! Delta: 16.530000000000015, in 52, out 1
# 211
# [local_search]: Improvement found! Delta: 11.629999999999987, in 89, out 22
# 212
# [local_search]: Improvement found! Delta: 26.30999999999999, in 1, out None
# 213
# [local_search]: Improvement found! Delta: 14.189999999999962, in 195, out 1
# 214
# [local_search]: Improvement found! Delta: 17.07999999999999, in 1, out None
# 215
# [local_search]: Improvement found! Delta: 21.74000000000001, in 68, out 1
# 216
# [local_search]: Improvement found! Delta: 10.410000000000002, in 22, out 89
# 217
# [local_search]: Improvement found! Delta: 16.320000000000007, in 13, out None
# 218
# [local_search]: Improvement found! Delta: 22.720000000000017, in 198, out 13
# 219
# [local_search]: Improvement found! Delta: 8.590000000000007, in 13, out None
# 220
# [local_search]: Improvement found! Delta: 13.48999999999999, in 32, out 13
# 221
# [local_search]: Improvement found! Delta: 6.310000000000004, in 89, out 32
# 222
# [local_search]: Improvement found! Delta: 6.4099999999999975, in 162, out 22
# 223
# [local_search]: Improvement found! Delta: 11.719999999999992, in 1, out None
# 224
# [local_search]: Improvement found! Delta: 12.870000000000017, in 22, out 1
# 225
# [local_search]: Improvement found! Delta: 8.76999999999999, in 32, out 89
# 226
# [local_search]: Improvement found! Delta: 5.969999999999988, in 131, out 43
# 227
# [local_search]: Improvement found! Delta: 15.29, in 136, out 118
# 228
# [local_search]: Improvement found! Delta: 15.260000000000012, in 44, out 52
# 229
# [local_search]: Improvement found! Delta: 17.400000000000016, in 167, out 196
# 230
# [local_search]: Improvement found! Delta: 18.00999999999998, in 1, out None
# 231
# [local_search]: Improvement found! Delta: 22.629999999999995, in 23, out None
# 232
# [local_search]: Improvement found! Delta: 17.479999999999993, in 43, out None
# 233
# [local_search]: Improvement found! Delta: 28.010000000000016, in 45, out None
# 234
# [local_search]: Improvement found! Delta: 25.040000000000035, in 144, out 1
# 235
# [local_search]: Improvement found! Delta: 16.19999999999998, in 1, out None
# 236
# [local_search]: Improvement found! Delta: 9.90999999999999, in 151, out 22
# 237
# [local_search]: Improvement found! Delta: 2.720000000000022, in 22, out 43
# 238
# [local_search]: Improvement found! Delta: 3.650000000000021, in 43, out 1
# 239
# [local_search]: Improvement found! Delta: 25.609999999999978, in 1, out None
# 240
# [local_search]: Improvement found! Delta: 14.710000000000004, in 35, out None
# 241
# [local_search]: Improvement found! Delta: 4.380000000000008, in 75, out 35
# 242
# [local_search]: Improvement found! Delta: 9.849999999999994, in 155, out 75
# 243
# [local_search]: Improvement found! Delta: 1.950000000000005, in 10, out None
# 244
# [local_search]: Improvement found! Delta: 11.99, in 104, out 10
# 245
# [local_search]: Improvement found! Delta: 11.630000000000003, in 35, out None
# 246
# [local_search]: Improvement found! Delta: 4.019999999999999, in 52, out 35
# 247
# [local_search]: Improvement found! Delta: 5.699999999999978, in 196, out 104
# 248
# [local_search]: Improvement found! Delta: 11.640000000000006, in 10, out None
# 249
# [local_search]: Improvement found! Delta: 9.089999999999982, in 73, out 52
# 250
# [local_search]: Improvement found! Delta: 11.000000000000004, in 35, out None
# 251
# [local_search]: Improvement found! Delta: 19.94, in 52, out None
# 252
# [local_search]: Improvement found! Delta: 12.069999999999997, in 64, out 35
# 253
# [local_search]: Improvement found! Delta: 2.22000000000001, in 20, out None
# 254
# [local_search]: Improvement found! Delta: 6.279999999999994, in 35, out 20
# 255
# [local_search]: Improvement found! Delta: 4.959999999999986, in 81, out 35
# 256
# [local_search]: Improvement found! Delta: 6.779999999999998, in 89, out 64
# 257
# [local_search]: Improvement found! Delta: 0.919999999999999, in 94, out 126
# 258
# [local_search]: Improvement found! Delta: 6.279999999999989, in 118, out 81
# 259
# [local_search]: Improvement found! Delta: 5.860000000000005, in 64, out None
# 260
# [local_search]: Improvement found! Delta: 22.51, in 81, out 64
# 261
# [local_search]: Improvement found! Delta: 2.1800000000000184, in 78, out None
# 262
# [local_search]: Improvement found! Delta: 17.34999999999998, in 126, out 78
# 263
# [local_search]: Improvement found! Delta: 7.73, in 145, out 126
# 264
# [local_search]: Improvement found! Delta: 0.3099999999999994, in 153, out 145
# 265
# [local_search]: Improvement found! Delta: 4.010000000000004, in 64, out None
# 266
# [local_search]: Improvement found! Delta: 14.799999999999992, in 126, out 64
# 267
# [local_search]: Improvement found! Delta: 7.7899999999999885, in 128, out 155
# 268
# [local_search]: Improvement found! Delta: 8.92000000000003, in 53, out 73
# 269
# [local_search]: Improvement found! Delta: 11.43, in 102, out 52
# 270
# [local_search]: Improvement found! Delta: 8.66000000000001, in 176, out 22
# 271
# [local_search]: Improvement found! Delta: 20.75999999999998, in 8, out None
# 272
# [local_search]: Improvement found! Delta: 5.089999999999995, in 22, out None
# 273
# [local_search]: Improvement found! Delta: 10.840000000000009, in 35, out 22
# 274
# [local_search]: Improvement found! Delta: 26.10000000000001, in 41, out None
# 275
# [local_search]: Improvement found! Delta: 4.199999999999996, in 22, out None
# 276
# [local_search]: Improvement found! Delta: 15.98, in 83, out 22
# 277
# [local_search]: Improvement found! Delta: 2.3900000000000103, in 115, out 94
# 278
# [local_search]: Improvement found! Delta: 4.61000000000001, in 20, out None
# 279
# [local_search]: Improvement found! Delta: 19.19999999999999, in 94, out 20
# 280
# [local_search]: Improvement found! Delta: 9.669999999999998, in 52, out None
# 281
# [local_search]: Improvement found! Delta: 7.220000000000002, in 54, out 52
# 282
# [local_search]: Improvement found! Delta: 11.78, in 161, out 54
# 283
# [local_search]: Improvement found! Delta: 2.1599999999999753, in 51, out None
# 284
# [local_search]: Improvement found! Delta: 20.040000000000024, in 127, out 51
# 285
# [local_search]: Improvement found! Delta: 4.9099999999999975, in 52, out None
# 286
# [local_search]: Improvement found! Delta: 16.770000000000003, in 54, out None
# 287
# [local_search]: Improvement found! Delta: 7.330000000000007, in 64, out 52
# 288
# [local_search]: Improvement found! Delta: 0.9899999999999851, in 134, out 64
# 289
# [local_search]: Improvement found! Delta: 7.949999999999978, in 51, out None
# 290
# [local_search]: Improvement found! Delta: 11.19000000000003, in 137, out 51
# 291
# [local_search]: Improvement found! Delta: 1.1399999999999975, in 52, out None
# 292
# [local_search]: Improvement found! Delta: 3.1399999999999952, in 64, out 137
# 293
# [local_search]: Improvement found! Delta: 10.98999999999998, in 51, out None
# 294
# [local_search]: Improvement found! Delta: 1.600000000000028, in 137, out 51
# 295
# [local_search]: Improvement found! Delta: 1.1699999999999804, in 51, out None
# 296
# [local_search]: Improvement found! Delta: 3.9500000000000055, in 78, out 137
# 297
# [local_search]: Improvement found! Delta: 7.540000000000015, in 133, out 134
# 298
# [local_search]: Improvement found! Delta: 1.1599999999999726, in 73, out None
# 299
# [local_search]: Improvement found! Delta: 9.530000000000017, in 134, out 73
# 300
# [local_search]: Improvement found! Delta: 5.719999999999974, in 117, out None
# 301
# [local_search]: Improvement found! Delta: 7.029999999999973, in 73, out None
# 302
# [local_search]: Improvement found! Delta: 4.300000000000003, in 111, out None
# 303
# [local_search]: Improvement found! Delta: 11.46, in 145, out None
# 304
# [local_search]: Improvement found! Delta: 7.579999999999996, in 169, out 35
# 305
# [local_search]: Improvement found! Delta: 6.549999999999972, in 61, out 176
# 306
# [local_search]: Improvement found! Delta: 2.2799999999999985, in 74, out None
# 307
# [local_search]: Improvement found! Delta: 12.400000000000007, in 175, out None
# 308
# [local_search]: Improvement found! Delta: 2.689999999999989, in 176, out 175
# 309
# [local_search]: Improvement found! Delta: 8.410000000000007, in 175, out None
# 310
# [local_search]: Improvement found! Delta: 3.109999999999959, in 3, out None
# 311
# [local_search]: Improvement found! Delta: 4.180000000000011, in 137, out None
# 312
# [local_search]: No improvement found after (312) iterations!
# Constructed solution (iteration 2): [13, 156, 10, 103, 81, 164, 93, 40, 3]
# 1
# [local_search]: Improvement found! Delta: 7.0399999999999965, in 0, out 93
# 2
# ...
# 130
# [local_search]: Improvement found! Delta: 18.300000000000004, in 43, out 41
# 131
# [local_search]: Improvement found! Delta: 9.560000000000002, in 0, out None
# 132
# [local_search]: Improvement found! Delta: 6.449999999999995, in 15, out 0
# 133
# [local_search]: Improvement found! Delta: 3.2100000000000017, in 53, out 15
# 134
# [local_search]: Improvement found! Delta: 15.530000000000001, in 76, out 53
# 135
# [local_search]: Improvement found! Delta: 11.800000000000002, in 0, out None
# 136
# [local_search]: Improvement found! Delta: 6.2900000000000045, in 39, out 0
# 137
# [local_search]: Improvement found! Delta: 37.47, in 169, out 39
# 138
# [local_search]: Improvement found! Delta: 4.200000000000003, in 91, out 76
# 139
# [local_search]: Improvement found! Delta: 9.550000000000002, in 0, out None
# 140
# [local_search]: Improvement found! Delta: 14.169999999999995, in 15, out 0
# 141
# [local_search]: Improvement found! Delta: 2.7600000000000033, in 41, out 15
# 142
# [local_search]: Improvement found! Delta: 17.499999999999996, in 172, out 41
# 143
# [local_search]: Improvement found! Delta: 5.240000000000002, in 0, out None
# 144
# [local_search]: Improvement found! Delta: 25.189999999999998, in 15, out 0
# 145
# [local_search]: Improvement found! Delta: 10.250000000000007, in 76, out 15
# 146
# [local_search]: Improvement found! Delta: 7.480000000000001, in 0, out None
# 147
# [local_search]: Improvement found! Delta: 21.9, in 15, out 0
# 148
# [local_search]: Improvement found! Delta: 2.689999999999987, in 54, out 15
# 149
# [local_search]: Improvement found! Delta: 5.97, in 99, out 54
# 150
# [local_search]: Improvement found! Delta: 1.1700000000000044, in 15, out 111
# 151
# [local_search]: Improvement found! Delta: 11.329999999999979, in 178, out 76
# 152
# [local_search]: Improvement found! Delta: 6.540000000000009, in 76, out 15
# 153
# [local_search]: Improvement found! Delta: 6.769999999999995, in 2, out None
# 154
# [local_search]: Improvement found! Delta: 31.43, in 15, out 2
# 155
# [local_search]: Improvement found! Delta: 5.909999999999995, in 2, out None
# 156
# [local_search]: Improvement found! Delta: 13.830000000000007, in 27, out 2
# 157
# [local_search]: Improvement found! Delta: 12.43, in 37, out 27
# 158
# [local_search]: Improvement found! Delta: 14.119999999999997, in 2, out None
# 159
# [local_search]: Improvement found! Delta: 7.770000000000012, in 39, out 2
# 160
# [local_search]: Improvement found! Delta: 12.259999999999994, in 54, out 39
# 161
# [local_search]: Improvement found! Delta: 9.849999999999987, in 87, out 37
# 162
# [local_search]: Improvement found! Delta: 7.880000000000009, in 113, out 87
# 163
# [local_search]: Improvement found! Delta: 14.329999999999991, in 123, out 76
# 164
# [local_search]: Improvement found! Delta: 13.640000000000004, in 18, out None
# 165
# [local_search]: Improvement found! Delta: 12.319999999999999, in 37, out 18
# 166
# [local_search]: Improvement found! Delta: 11.309999999999992, in 41, out 37
# 167
# [local_search]: Improvement found! Delta: 14.120000000000022, in 98, out 106
# 168
# [local_search]: Improvement found! Delta: 10.720000000000022, in 126, out 13
# 169
# [local_search]: Improvement found! Delta: 9.840000000000016, in 13, out 32
# 170
# [local_search]: Improvement found! Delta: 23.550000000000033, in 142, out 13
# 171
# [local_search]: Improvement found! Delta: 8.999999999999996, in 159, out 7
# 172
# [local_search]: Improvement found! Delta: 42.49000000000001, in 7, out None
# 173
# [local_search]: Improvement found! Delta: 50.62999999999999, in 13, out None
# 174
# [local_search]: Improvement found! Delta: 5.229999999999993, in 111, out 7
# 175
# [local_search]: Improvement found! Delta: 49.87000000000002, in 7, out None
# 176
# [local_search]: Improvement found! Delta: 12.479999999999974, in 174, out 7
# 177
# [local_search]: Improvement found! Delta: 48.09000000000002, in 7, out None
# 178
# [local_search]: Improvement found! Delta: 9.98999999999998, in 25, out None
# 179
# [local_search]: Improvement found! Delta: 12.590000000000003, in 27, out 25
# 180
# [local_search]: Improvement found! Delta: 9.06, in 102, out 27
# 181
# [local_search]: Improvement found! Delta: 15.120000000000008, in 144, out 102
# 182
# [local_search]: Improvement found! Delta: 4.300000000000005, in 161, out 7
# 183
# [local_search]: Improvement found! Delta: 41.31000000000002, in 7, out None
# 184
# [local_search]: Improvement found! Delta: 11.469999999999967, in 32, out 7
# 185
# [local_search]: Improvement found! Delta: 34.110000000000014, in 7, out None
# 186
# [local_search]: Improvement found! Delta: 15.469999999999988, in 189, out 7
# 187
# [local_search]: Improvement found! Delta: 0.8699999999999963, in 0, out None
# 188
# [local_search]: Improvement found! Delta: 25.529999999999987, in 25, out 0
# 189
# [local_search]: Improvement found! Delta: 22.71000000000001, in 7, out None
# 190
# [local_search]: Improvement found! Delta: 26.919999999999998, in 37, out 7
# 191
# [local_search]: Improvement found! Delta: 21.86000000000001, in 7, out None
# 192
# [local_search]: Improvement found! Delta: 13.999999999999993, in 76, out 7
# 193
# [local_search]: Improvement found! Delta: 24.99000000000001, in 7, out None
# 194
# [local_search]: Improvement found! Delta: 17.309999999999995, in 115, out 7
# 195
# [local_search]: Improvement found! Delta: 10.230000000000018, in 171, out 25
# 196
# [local_search]: Improvement found! Delta: 11.729999999999997, in 0, out None
# 197
# [local_search]: Improvement found! Delta: 38.43000000000001, in 7, out None
# 198
# [local_search]: Improvement found! Delta: 32.050000000000004, in 129, out 0
# 199
# [local_search]: Improvement found! Delta: 8.019999999999998, in 0, out None
# 200
# [local_search]: Improvement found! Delta: 39.249999999999986, in 25, out None
# 201
# [local_search]: Improvement found! Delta: 35.34, in 47, out 0
# 202
# [local_search]: Improvement found! Delta: 4.289999999999994, in 160, out 47
# 203
# [local_search]: Improvement found! Delta: 33.29999999999999, in 27, out None
# 204
# [local_search]: Improvement found! Delta: 27.519999999999996, in 35, out None
# 205
# [local_search]: Improvement found! Delta: 8.590000000000003, in 40, out 35
# 206
# [local_search]: Improvement found! Delta: 21.569999999999997, in 35, out None
# 207
# [local_search]: Improvement found! Delta: 24.650000000000002, in 47, out 35
# 208
# [local_search]: Improvement found! Delta: 13.649999999999995, in 105, out 7
# 209
# [local_search]: Improvement found! Delta: 11.92000000000002, in 141, out 13
# 210
# [local_search]: Improvement found! Delta: 5.5999999999999925, in 150, out 118
# 211
# [local_search]: Improvement found! Delta: 21.910000000000043, in 68, out 50
# 212
# [local_search]: Improvement found! Delta: 4.729999999999999, in 1, out None
# 213
# [local_search]: Improvement found! Delta: 12.659999999999998, in 17, out 1
# 214
# [local_search]: Improvement found! Delta: 24.18, in 102, out 17
# 215
# [local_search]: Improvement found! Delta: 13.789999999999996, in 166, out 111
# 216
# [local_search]: Improvement found! Delta: 11.91, in 85, out 115
# 217
# [local_search]: Improvement found! Delta: 5.820000000000014, in 110, out 144
# 218
# [local_search]: Improvement found! Delta: 2.7800000000000056, in 36, out 40
# 219
# [local_search]: Improvement found! Delta: 6.609999999999983, in 144, out 85
# 220
# [local_search]: Improvement found! Delta: 15.439999999999998, in 6, out None
# 221
# [local_search]: Improvement found! Delta: 6.899999999999999, in 35, out 6
# 222
# [local_search]: Improvement found! Delta: 10.610000000000015, in 39, out 35
# 223
# [local_search]: Improvement found! Delta: 19.13, in 6, out None
# 224
# [local_search]: Improvement found! Delta: 7.830000000000004, in 40, out 6
# 225
# [local_search]: Improvement found! Delta: 11.04, in 78, out 39
# 226
# [local_search]: Improvement found! Delta: 15.689999999999992, in 13, out None
# 227
# [local_search]: Improvement found! Delta: 25.869999999999994, in 118, out 13
# 228
# [local_search]: Improvement found! Delta: 20.629999999999992, in 13, out None
# 229
# [local_search]: Improvement found! Delta: 18.989999999999995, in 154, out 13
# 230
# [local_search]: Improvement found! Delta: 20.539999999999992, in 13, out None
# 231
# [local_search]: Improvement found! Delta: 12.190000000000012, in 85, out 13
# 232
# [local_search]: Improvement found! Delta: 20.78, in 195, out 85
# 233
# [local_search]: Improvement found! Delta: 2.63, in 163, out 118
# 234
# [local_search]: Improvement found! Delta: 3.3999999999999986, in 6, out None
# 235
# [local_search]: Improvement found! Delta: 17.589999999999993, in 13, out 6
# 236
# [local_search]: Improvement found! Delta: 12.320000000000014, in 85, out 13
# 237
# [local_search]: Improvement found! Delta: 15.929999999999993, in 13, out None
# 238
# [local_search]: Improvement found! Delta: 12.99000000000002, in 39, out 13
# 239
# [local_search]: Improvement found! Delta: 10.189999999999994, in 80, out 39
# 240
# [local_search]: Improvement found! Delta: 10.279999999999992, in 13, out None
# 241
# [local_search]: Improvement found! Delta: 18.60000000000002, in 39, out 13
# 242
# [local_search]: Improvement found! Delta: 19.719999999999956, in 175, out 83
# 243
# [local_search]: Improvement found! Delta: 13.340000000000007, in 13, out None
# 244
# [local_search]: Improvement found! Delta: 32.93000000000001, in 17, out None
# 245
# [local_search]: Improvement found! Delta: 16.500000000000004, in 83, out 13
# 246
# [local_search]: Improvement found! Delta: 6.839999999999997, in 60, out 17
# 247
# [local_search]: Improvement found! Delta: 7.730000000000008, in 118, out 60
# 248
# [local_search]: Improvement found! Delta: 13.019999999999978, in 184, out 118
# 249
# [local_search]: Improvement found! Delta: 14.450000000000006, in 13, out None
# 250
# [local_search]: Improvement found! Delta: 24.95000000000001, in 17, out None
# 251
# [local_search]: Improvement found! Delta: 5.110000000000002, in 52, out 13
# 252
# [local_search]: Improvement found! Delta: 16.860000000000007, in 13, out None
# 253
# [local_search]: Improvement found! Delta: 12.27, in 118, out 13
# 254
# [local_search]: Improvement found! Delta: 21.800000000000008, in 13, out None
# 255
# [local_search]: Improvement found! Delta: 3.37999999999999, in 153, out 17
# 256
# [local_search]: Improvement found! Delta: 27.810000000000013, in 17, out None
# 257
# [local_search]: Improvement found! Delta: 5.839999999999996, in 33, out None
# 258
# [local_search]: Improvement found! Delta: 9.929999999999996, in 63, out 33
# 259
# [local_search]: Improvement found! Delta: 11.139999999999997, in 33, out None
# 260
# [local_search]: Improvement found! Delta: 7.2699999999999925, in 72, out 118
# 261
# [local_search]: Improvement found! Delta: 16.200000000000003, in 60, out None
# 262
# [local_search]: Improvement found! Delta: 11.619999999999994, in 97, out 60
# 263
# [local_search]: Improvement found! Delta: 9.84000000000001, in 118, out 33
# 264
# [local_search]: Improvement found! Delta: 19.699999999999996, in 33, out None
# 265
# [local_search]: Improvement found! Delta: 6.399999999999978, in 146, out 124
# 266
# [local_search]: Improvement found! Delta: 15.640000000000004, in 60, out None
# 267
# [local_search]: Improvement found! Delta: 14.909999999999968, in 89, out 141
# 268
# [local_search]: Improvement found! Delta: 12.83, in 115, out 78
# 269
# [local_search]: Improvement found! Delta: 18.680000000000007, in 78, out None
# 270
# [local_search]: Improvement found! Delta: 18.96, in 81, out None
# 271
# [local_search]: Improvement found! Delta: 11.239999999999979, in 94, out 60
# 272
# [local_search]: Improvement found! Delta: 17.659999999999975, in 128, out 129
# 273
# [local_search]: Improvement found! Delta: 17.28999999999999, in 51, out None
# 274
# [local_search]: Improvement found! Delta: 3.510000000000031, in 129, out 51
# 275
# [local_search]: Improvement found! Delta: 11.599999999999987, in 162, out 169
# 276
# [local_search]: Improvement found! Delta: 4.120000000000014, in 145, out 94
# 277
# [local_search]: Improvement found! Delta: 6.249999999999986, in 173, out 78
# 278
# [local_search]: Improvement found! Delta: 1.5400000000000134, in 177, out 118
# 279
# [local_search]: Improvement found! Delta: 5.03999999999998, in 118, out 128
# 280
# [local_search]: Improvement found! Delta: 2.020000000000003, in 1, out None
# 281
# [local_search]: Improvement found! Delta: 4.289999999999999, in 4, out 1
# 282
# [local_search]: Improvement found! Delta: 3.369999999999985, in 94, out 4
# 283
# [local_search]: Improvement found! Delta: 15.090000000000002, in 128, out 94
# 284
# [local_search]: Improvement found! Delta: 0.880000000000009, in 0, out None
# 285
# [local_search]: Improvement found! Delta: 3.029999999999993, in 4, out 0
# 286
# [local_search]: Improvement found! Delta: 18.860000000000003, in 197, out 4
# 287
# [local_search]: Improvement found! Delta: 3.510000000000006, in 30, out None
# 288
# [local_search]: Improvement found! Delta: 11.129999999999978, in 94, out 30
# 289
# [local_search]: Improvement found! Delta: 1.2900000000000091, in 0, out None
# 290
# [local_search]: Improvement found! Delta: 9.950000000000014, in 169, out 0
# 291
# [local_search]: Improvement found! Delta: 12.150000000000004, in 1, out None
# 292
# [local_search]: Improvement found! Delta: 10.469999999999999, in 187, out 1
# 293
# [local_search]: Improvement found! Delta: 4.9200000000000035, in 1, out None
# 294
# [local_search]: Improvement found! Delta: 14.970000000000008, in 167, out 1
# 295
# [local_search]: Improvement found! Delta: 13.800000000000004, in 1, out None
# 296
# [local_search]: Improvement found! Delta: 12.109999999999987, in 10, out None
# 297
# [local_search]: Improvement found! Delta: 6.23000000000001, in 0, out None
# 298
# [local_search]: Improvement found! Delta: 5.799999999999962, in 51, out 169
# 299
# [local_search]: Improvement found! Delta: 1.770000000000012, in 169, out 0
# 300
# [local_search]: Improvement found! Delta: 9.550000000000011, in 0, out None
# 301
# [local_search]: Improvement found! Delta: 10.72000000000001, in 53, out None
# 302
# [local_search]: Improvement found! Delta: 12.749999999999993, in 134, out 0
# 303
# [local_search]: Improvement found! Delta: 10.660000000000007, in 44, out None
# 304
# [local_search]: Improvement found! Delta: 5.009999999999968, in 73, out None
# 305
# [local_search]: Improvement found! Delta: 15.419999999999982, in 133, out None
# 306
# [local_search]: Improvement found! Delta: 12.880000000000035, in 176, out 73
# 307
# [local_search]: Improvement found! Delta: 10.429999999999996, in 87, out None
# 308
# [local_search]: Improvement found! Delta: 5.679999999999998, in 100, out 169
# 309
# [local_search]: Improvement found! Delta: 8.040000000000019, in 34, out None
# 310
# [local_search]: Improvement found! Delta: 4.63, in 60, out None
# 311
# [local_search]: Improvement found! Delta: 1.5399999999999912, in 131, out 13
# 312
# [local_search]: Improvement found! Delta: 2.1400000000000174, in 136, out 51
# 313
# [local_search]: Improvement found! Delta: 17.719999999999967, in 86, out 134
# 314
# [local_search]: Improvement found! Delta: 4.929999999999992, in 135, out 145
# 315
# [local_search]: Improvement found! Delta: 20.680000000000014, in 137, out 39
# 316
# [local_search]: Improvement found! Delta: 9.439999999999984, in 190, out 52
# 317
# [local_search]: Improvement found! Delta: 11.579999999999973, in 50, out 115
# 318
# [local_search]: Improvement found! Delta: 17.469999999999995, in 23, out 10
# 319
# [local_search]: Improvement found! Delta: 5.100000000000008, in 8, out None
# 320
# [local_search]: Improvement found! Delta: 9.269999999999989, in 26, out None
# 321
# [local_search]: Improvement found! Delta: 23.690000000000012, in 74, out None
# 322
# [local_search]: Improvement found! Delta: 6.969999999999993, in 198, out None
# 323
# [local_search]: No improvement found after (323) iterations!
#
# Best solution found:
# Selected elements: [90, 46, 71, 196, 67, 72, 91, 97, 118, 47, 157, 110, 25, 36, 105, 15, 92, 142, 146, 5, 150, 37, 113, 85, 87, 12, 136, 119, 11, 94, 154, 158, 69, 148, 9, 14, 22, 174, 114, 125, 48, 116, 163, 179, 192, 89, 28, 189, 65, 99, 112, 98, 161, 159, 27, 76, 38, 43, 172, 178, 166, 40, 60, 50, 123, 173, 129, 131, 147, 23, 137, 187, 41, 44, 126, 81, 167, 49, 53, 135, 10, 68, 102, 54, 128, 151, 80, 153, 171, 32, 1, 127, 175, 176, 83, 177, 115, 145, 0, 79, 111, 139, 124, 133, 144, 160, 132, 168, 35, 78, 13, 164, 59, 86, 195, 16]
# Objective value: 4543.800000000004
# Coverage: 100.00%
